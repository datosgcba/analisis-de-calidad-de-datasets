# %%
import pandas as pd
import numpy as np
import re
import requests

# %%
data=pd.read_csv('hospitales_gcba.csv')

# %%
data
# Out:
#                                             WKT    ID  \
# 0   POINT (-58.3775508488443 -34.6288473603882)   1.0
# 1   POINT (-58.4120700769456 -34.5941919726393)   2.0
# 2   POINT (-58.4005143372538 -34.5847671286454)   4.0
# 3   POINT (-58.3851559118889 -34.6394041316484)   6.0
# 4   POINT (-58.3913114406535 -34.6341535760002)   7.0
# 5   POINT (-58.4349433479819 -34.6084721257413)   8.0
# 6   POINT (-58.3758433488021 -34.6302112044495)   9.0
# 7   POINT (-58.3823284509488 -34.6357022351559)  10.0
# 8   POINT (-58.3821283746958 -34.6364350546569)  11.0
# 9   POINT (-58.3601201271455 -34.6388917320834)  12.0
# 10  POINT (-58.4409882382439 -34.5538963316473)  13.0
# 11   POINT (-58.4027506275377 -34.634856308415)  14.0
# 12  POINT (-58.4601855775528 -34.6054342750207)  15.0
# 13  POINT (-58.4276597542837 -34.6146348348429)  16.0
# 14  POINT (-58.4332484381295 -34.6070507603866)  17.0
# 15  POINT (-58.4323966950244 -34.6255031952483)  18.0
# ...

# %%
data.WKT.str.replace('POINT', '')
data.WKT.str.split(' ', expand=True)

data['long']=data.WKT.str.split(' ', expand=True)[1]
data['lat']=data.WKT.str.split(' ', expand=True)[2]

data.long=data.long.str.strip("(")
data.lat=data.lat.str.strip(")")

# %%
data=data[['long', 'lat', 'ID', 'NOMBRE', 'NOM_MAP', 'OBJETO', 'CALLE', 'ALTURA', 'DOM_GEO', 'TELEFONO', 'GUARDIA', 'FAX', 'WEB',
          'TIPO', 'TIPO_ESPEC', 'MOD_AT_1', 'MOD_AT_2','DEPEND_ADM', 'DIRECTOR', 'DOM_NORMA', 'BARRIO', 'COMUNA', 'CODIGO_POS','COD_POSTAL',
          'VHI','SERVICIOS_', 'EFE_SALUD', 'VACUNAT_']]

# %%
data.columns=['long', 'lat', 'id', 'nombre', 'nom_map', 'objeto', 'calle', 'altura',
       'dom_geo', 'telefono', 'guardia', 'fax', 'web', 'tipo', 'tipo_espec',
       'mod_at_1', 'mod_at_2', 'depend_adm', 'director', 'dom_norma', 'barrio',
       'comuna', 'codigo_postal', 'codigo_postal_argentino', 'vhi', 'servicios_', 'efe_salud',
       'vacunat_']

# %%
data['comuna']=data['comuna'].str.replace('COMUNA ', '')
# Out:
# C:\Users\rama_\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
data['id']=data['id'].fillna(0).astype(int)
# Out:
# C:\Users\rama_\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
data.to_csv('hospitales-20180914.csv', index=False)
