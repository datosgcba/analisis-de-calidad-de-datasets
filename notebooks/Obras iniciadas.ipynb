# %%
import pandas as pd
import numpy as np
import re
import requests

# %%
data=pd.read_csv('Obras (26).xls', encoding='UTF-8', sep='\t')

# %%
data=data.iloc[:,0:26]

# %%
data.columns
# Out:
# Index(['Calle', 'CalleNro', 'Seccion', 'Manzana', 'Parcela', 'Exp_DGROC',
#        'Superficie', 'Fecha_inicio_obra', 'Fecha_ultima_inspeccion',
#        'Motivo_ultima_inspeccion', 'Estado', 'Ultimo_AVO_solicitado',
#        'Fecha_ultimo_AVO', 'Comisaria', 'Comuna', 'Cargada_con_DO',
#        'EstadoTramite', 'AvosRequeridas', 'AvosSolicitados', 'Profesional',
#        'Barrios', 'MetrosAConstruir', 'Fecha_Estado_Tramite',
#        'Email_Profesional', 'Tipo_Obra', 'Destino'],
#       dtype='object')

# %%
data.columns= ['calle', 'calle_nro', 'seccion', 'manzana', 'parcela', 'exp_DGROC',
       'superficie', 'fecha_inicio_obra', 'fecha_ultima_inspeccion',
       'motivo_ultima_inspeccion', 'estado', 'ultimo_avo_solicitado',
       'fecha_ultimo_avo', 'comisaria', 'comuna', 'cargada_con_do',
       'estado_tramite', 'avos_requeridas', 'avos_solicitados', 'profesional',
       'barrio', 'metros_a_construir', 'fecha_estado_tramite',
       'email_profesional', 'tipo_obra', 'destino']

# %%
data=data[['calle', 'calle_nro', 'seccion', 'manzana', 'parcela', 'exp_DGROC', 'fecha_inicio_obra', 'estado', 'ultimo_avo_solicitado',
       'fecha_ultimo_avo', 'comisaria', 'comuna', 'cargada_con_do',
       'estado_tramite', 'profesional',
       'barrio', 'metros_a_construir', 'fecha_estado_tramite',
       'tipo_obra', 'destino']]

# %%
data=data[data['cargada_con_do'] == 'SI']

# %%
data=data.reset_index()

# %%
data.calle_nro[data.calle_nro.isnull()]
# Out:
# 378    NaN
# 2017   NaN
# Name: calle_nro, dtype: float64

# %%
data.calle_nro=pd.Series(data.calle_nro.values.astype(int))

# %%
data['calle_nro']
# Out:
# 0       1325
# 1       1762
# 2        326
# 3       1874
# 4       2925
# 5        569
# 6       3225
# 7       3225
# 8        782
# 9       5958
# 10      3223
# 11      2450
# 12      1886
# 13      3141
# 14      3141
# 15      5923
# 16      1946
# 17      3418
# 18      2881
# 19        37
# 20        37
# 21      1117
# 22      5551
# 23      3609
# 24      6322
# 25      3851
# 26      1463
# 27      3487
# 28      1478
# 29       837
#         ...
# 5203     460
# 5204    3149
# 5205    3456
# 5206    4557
# 5207    3579
# 5208    2831
# 5209    2356
# 5210    1631
# 5211    1631
# 5212    1631
# 5213    1631
# 5214     138
# 5215    1554
# 5216    1450
# 5217     146
# 5218    4467
# 5219    3211
# 5220    1885
# 5221    5826
# 5222    2936
# 5223    4519
# 5224    6661
# 5225    1519
# 5226     319
# 5227    2389
# 5228    1460
# 5229    6677
# 5230    1391
# 5231    4922
# 5232    5765
# Name: calle_nro, Length: 5233, dtype: int32

# %%
data
# Out:
#       index                        calle  calle_nro  seccion manzana parcela  \
# 0         1        ALVEAR, MARCELO T. DE       1325        7     040     019
# 1         2                  VERDI, JOSE       1762       87    001B    008
# 2         3                       THAMES        326       47    158     022
# 3         4                 SAN JUAN AV.       1874       22    065A    008
# 4         8      FLORES, VENANCIO, GRAL.       2925       65    022     022A
# 5         9                         POLA        569       60    022     024
# 6        10           GARAY, JUAN DE AV.       3225       30    032     021
# 7        11           GARAY, JUAN DE AV.       3225       30    032     021
# 8        13               LINIERS VIRREY        782       28    018     020
# 9        17   FALCON, RAMON L.,CNEL. AV.       5958       60    053     002H
# 10       20                      QUEVEDO       3223       87     054     020
# ...

# %%
data=data[['calle', 'calle_nro', 'seccion', 'manzana', 'parcela', 'exp_DGROC', 'fecha_inicio_obra', 'estado', 'ultimo_avo_solicitado',
       'fecha_ultimo_avo', 'comisaria', 'comuna', 'cargada_con_do',
       'estado_tramite', 'profesional',
       'barrio', 'metros_a_construir', 'fecha_estado_tramite',
       'tipo_obra', 'destino']]

# %%
# df = pd.value_counts(data.superficie).to_frame().reset_index()

# %%
# df

# %%
data['CALLE_ALTURA']=data['calle']+ ' ' + data['calle_nro'].fillna('').astype(str)

# %%
direccion_url=[]
for i in data['CALLE_ALTURA']:
    try:
        direccion_url.append('http://servicios.usig.buenosaires.gob.ar/normalizar/?direccion='+i+',caba&geocodificar=TRUE')
    except:
        direccion_url.append(np.nan)

# %%
direccion_url
# Out:
# ['http://servicios.usig.buenosaires.gob.ar/normalizar/?direccion=ALVEAR, MARCELO T. DE 1325,caba&geocodificar=TRUE',
#  'http://servicios.usig.buenosaires.gob.ar/normalizar/?direccion=VERDI, JOSE 1762,caba&geocodificar=TRUE',
#  'http://servicios.usig.buenosaires.gob.ar/normalizar/?direccion=THAMES 326,caba&geocodificar=TRUE',
#  'http://servicios.usig.buenosaires.gob.ar/normalizar/?direccion=SAN JUAN AV. 1874,caba&geocodificar=TRUE',
#  'http://servicios.usig.buenosaires.gob.ar/normalizar/?direccion=FLORES, VENANCIO, GRAL. 2925,caba&geocodificar=TRUE',
#  'http://servicios.usig.buenosaires.gob.ar/normalizar/?direccion=POLA 569,caba&geocodificar=TRUE',
#  'http://servicios.usig.buenosaires.gob.ar/normalizar/?direccion=GARAY, JUAN DE AV. 3225,caba&geocodificar=TRUE',
#  'http://servicios.usig.buenosaires.gob.ar/normalizar/?direccion=GARAY, JUAN DE AV. 3225,caba&geocodificar=TRUE',
# ...

# %%
def get_x(dir):
    try:
        response= requests.get(dir)
        pattern='"x":."(.\d+.\d+)"'
        
        if (re.findall(pattern, response.text)!=[]):
            x.append(re.findall(pattern, response.text)[0])
            print('.')
        else:
            x.append(np.nan)
            print( i )
    except:
        x.append(np.nan)
        print('sin URL')

# %%
x=[]
for i in direccion_url:
    get_x(i)
# Out:
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# http://servicios.usig.buenosaires.gob.ar/normalizar/?direccion=CALLE SIN NOMBRE OFICIAL 690,caba&geocodificar=TRUE
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ...

# %%
x
# Out:
# ['-58.386029',
#  '-58.511713',
#  '-58.445451',
#  '-58.392494',
#  '-58.470892',
#  '-58.507663',
#  '-58.410394',
#  '-58.410394',
#  '-58.413791',
#  '-58.510447',
#  '-58.516921',
#  '-58.422431',
#  '-58.432934',
#  '-58.391466',
#  '-58.391466',
#  '-58.507030',
#  '-58.460895',
#  '-58.509856',
#  '-58.478217',
#  '-58.468087',
#  '-58.468087',
#  '-58.382375',
#  '-58.496601',
#  '-58.417521',
#  '-58.504482',
#  '-58.513408',
#  '-58.481214',
#  '-58.478627',
#  '-58.437455',
#  '-58.429867',
#  '-58.460113',
#  '-58.503400',
#  '-58.428251',
#  '-58.464096',
#  '-58.464096',
#  '-58.448398',
#  '-58.448398',
#  '-58.460859',
#  '-58.490452',
#  '-58.370737',
#  '-58.491443',
#  '-58.491443',
#  '-58.370149',
#  '-58.509526',
#  '-58.519646',
#  '-58.428679',
#  '-58.513402',
#  '-58.521135',
#  '-58.450656',
#  '-58.441468',
#  '-58.515513',
#  '-58.480227',
#  '-58.397725',
#  '-58.397725',
#  '-58.437090',
#  '-58.480350',
#  '-58.493831',
#  '-58.438470',
# ...

# %%
def get_lat(url):
    try:
        response= requests.get(url)
        pattern='"y":."(.*?)"'
        if (re.findall(pattern, response.text)!=[]):
                lat.append(re.findall(pattern, response.text)[0])
                print('.')
        else:
            lat.append(np.nan)
            print( i )
       
    except:
        lat.append(np.nan)
        print('sin URL')

# %%
lat=[]
for i in direccion_url:
    get_lat(i)
# Out:
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# http://servicios.usig.buenosaires.gob.ar/normalizar/?direccion=CALLE SIN NOMBRE OFICIAL 690,caba&geocodificar=TRUE
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ...

# %%
def get_calle(url):
    try:
        response= requests.get(url)
        pattern='"nombre_calle":."(.*?)"'
        if (re.findall(pattern, response.text)!=[]):
                calle.append(re.findall(pattern, response.text)[0])
                print('.')
        else:
            calle.append(np.nan)
            print('sin calle')
    except:
        calle.append(np.nan)
        print('sin URL')

# %%
calle=[]
for i in direccion_url:
    get_calle(i)
    print
# Out:
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# sin calle
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ...

# %%
def get_altura(url):
    try:
        response= requests.get(url)
        pattern='"altura":.(\d+)'
        if (re.findall(pattern, response.text)!=[]):
                altura.append(re.findall(pattern, response.text)[0])
                print('.')
        else:
            altura.append(np.nan)
            print('sin altura') 
    except:
        altura.append(np.nan)
        print('sin URL')

# %%
altura=[]
for i in direccion_url:
    get_altura(i)
    print
# Out:
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# sin altura
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ...

# %%
datos_utiles_url=[]
for i in data['calle']:
    try:
        datos_utiles_url.append('http://ws.usig.buenosaires.gob.ar/datos_utiles/?callback=?&calle='+i+'&altura=')
    except:
        datos_utiles_url.append(np.nan)
        print('es un nan')
# Out:
# es un nan

# %%
datos_utiles_url_=pd.Series(datos_utiles_url)+data['calle_nro'].astype(str)

# %%
datos_utiles_url_.values
# Out:
# array(['http://ws.usig.buenosaires.gob.ar/datos_utiles/?callback=?&calle=ALVEAR, MARCELO T. DE&altura=1325',
#        'http://ws.usig.buenosaires.gob.ar/datos_utiles/?callback=?&calle=VERDI, JOSE&altura=1762',
#        'http://ws.usig.buenosaires.gob.ar/datos_utiles/?callback=?&calle=THAMES&altura=326',
#        ...,
#        'http://ws.usig.buenosaires.gob.ar/datos_utiles/?callback=?&calle=ZAPIOLA&altura=1391',
#        'http://ws.usig.buenosaires.gob.ar/datos_utiles/?callback=?&calle=IBERA&altura=4922',
#        'http://ws.usig.buenosaires.gob.ar/datos_utiles/?callback=?&calle=VEGA, NICETO, CNEL. AV.&altura=5765'],
#       dtype=object)

# %%
altura_url=data['calle_nro'].values.astype(str)

# %%
def get_comuna(url):
    try:
        response= requests.get(url)
        pattern='"comuna":"(Comuna.\d+)"'
        if response.status_code == 200:
            comuna.append(re.findall(pattern, response.text)[0])
            print('.')

        return comuna
    except:
        print('XXXX')
        comuna.append(np.nan)

# %%
comuna=[]
for i in datos_utiles_url_:
    get_comuna(i)
# Out:
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# XXXX
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ...

# %%
def get_barrio(url):
    try:
        response= requests.get(url)
        pattern='"barrio":"(.*?)"'
        if response.status_code == 200:
            barrio.append(re.findall(pattern, response.text)[0])
            print('.')


        return barrio
    except:
        print('XXXX')
        barrio.append(np.nan)

# %%
barrio=[]
for i in datos_utiles_url_:
    get_barrio(i)
# Out:
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# XXXX
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ...

# %%
def get_cp(url):
    try:
        response= requests.get(url)
        pattern='"codigo_postal":"(.*?)"'
        if response.status_code == 200:
            cp.append(re.findall(pattern, response.text)[0])
            print('.')

        return cp
    except:
        print('XXXX')
        cp.append(np.nan)

# %%
cp=[]
for i in datos_utiles_url_:
    get_cp(i)
# Out:
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# XXXX
# .
# XXXX
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# XXXX
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ...

# %%
def get_cpa(url):
    try:
        response= requests.get(url)
        pattern='"codigo_postal_argentino":"(.*?)"'
        if response.status_code == 200:
            cpa.append(re.findall(pattern, response.text)[0])
            print('.')

        return cpa
    except:
        print('XXXX'+ i)
        cpa.append(np.nan)

# %%
cpa=[]
for i in datos_utiles_url_:
    get_cpa(i)
# Out:
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# XXXXhttp://ws.usig.buenosaires.gob.ar/datos_utiles/?callback=?&calle=CALLE SIN NOMBRE OFICIAL&altura=690
# .
# XXXXhttp://ws.usig.buenosaires.gob.ar/datos_utiles/?callback=?&calle=ESPAÑA AV.&altura=1850
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# XXXXhttp://ws.usig.buenosaires.gob.ar/datos_utiles/?callback=?&calle=DUPUY&altura=1065
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ...

# %%
x= pd.Series(x)
lat= pd.Series(lat)
calle= pd.Series(calle)
altura= pd.Series(altura)
barrio= pd.Series(barrio)
comuna= pd.Series(comuna)
cp= pd.Series(cp)
cpa= pd.Series(cpa)

# %%
#cargada_con_do va?
#las 'Ó' estaban mal extraidas, aparecia el caracter 'Ã“'
#las 'Ñ' estaban mal extraidas, aparecia el caracter 'Ã‘'

# %%
df = pd.value_counts(data.tipo_obra).to_frame().reset_index()

# %%
df
# Out:
#                                                 index  tipo_obra
# 0                       DEMOLICION TOTAL Y OBRA NUEVA       2541
# 1                                          OBRA NUEVA       1189
# 2                                    DEMOLICION TOTAL        520
# 3                   AMP., MODIF. Y DEMOLICION PARCIAL        475
# 4                           MODIFICACION Y AMPLIACION        157
# 5             DEMOLICION PARCIAL Y AMPLIACION DE OBRA        113
# 6                       DEMOLICIÓN TOTAL Y OBRA NUEVA         30
# 7                     DEMOLICION PARCIAL Y OBRA NUEVA         21
# 8    AMPLIACION Y/O MODIFICACION C/DEMOLICION PARCIAL         21
# 9                                  DEMOLICION PARCIAL         11
# 10   AMPLIACIÓN Y MODIFICACIÓN CON DEMOLICIÓN PARCIAL         10
# 11                                                            10
# 12                                   DEMOLICIÓN TOTAL          8
# ...

# %%
#metros a construir en int

# %%
data.to_csv('obras-iniciadas-20181106.csv', index=False)

# %%
data2=pd.read_csv('obras-iniciadas-20181106.csv')

# %%
data2.columns
# Out:
# Index(['calle', 'calle_nro', 'seccion', 'manzana', 'parcela', 'exp_DGROC',
#        'fecha_inicio_obra', 'estado', 'ultimo_avo_solicitado',
#        'fecha_ultimo_avo', 'comisaria', 'comuna', 'cargada_con_do',
#        'estado_tramite', 'profesional', 'barrio', 'metros_a_construir',
#        'fecha_estado_tramite', 'tipo_obra', 'destino', 'CALLE_ALTURA', '0',
#        '1', '2', '3', '4', '0.1'],
#       dtype='object')

# %%
data2=data2[['calle', 'calle_nro', 'seccion', 'manzana', 'parcela', 'exp_DGROC',
       'fecha_inicio_obra', 'estado', 'ultimo_avo_solicitado',
       'fecha_ultimo_avo',
       'estado_tramite', 'profesional', 'barrio', 'metros_a_construir',
       'fecha_estado_tramite', 'tipo_obra', 'destino', '0',
       '1', '2', '3', '4', '0.1']]

# %%
data2.columns=['calle', 'calle_nro', 'seccion', 'manzana', 'parcela', 'expediente',
       'fecha_inicio_obra', 'estado', 'ultimo_avo_solicitado',
       'fecha_ultimo_avo', 'estado_tramite', 'profesional', 'barrio',
       'metros_a_construir', 'fecha_estado_tramite', 'tipo_obra', 'destino',
       'long', 'lat', 'barrio', 'comuna', 'codigo_postal', 'codigo_postal_argentino']

# %% [markdown]
# ## USAR ARREGLO DE FECHAS DEL OTRO SCRIPT

# %%
data2
# Out:
#                             calle  calle_nro  seccion manzana parcela  \
# 0           ALVEAR, MARCELO T. DE       1325        7     040     019
# 1                     VERDI, JOSE       1762       87    001B    008
# 2                          THAMES        326       47    158     022
# 3                    SAN JUAN AV.       1874       22    065A    008
# 4         FLORES, VENANCIO, GRAL.       2925       65    022     022A
# 5                            POLA        569       60    022     024
# 6              GARAY, JUAN DE AV.       3225       30    032     021
# 7              GARAY, JUAN DE AV.       3225       30    032     021
# 8                  LINIERS VIRREY        782       28    018     020
# 9      FALCON, RAMON L.,CNEL. AV.       5958       60    053     002H
# 10                        QUEVEDO       3223       87     054     020
# 11                         THAMES       2450       19    173     020B
# ...

# %%
data2.fecha_inicio_obra=data2.fecha_inicio_obra.apply(lambda x: pd.to_datetime(x, format='%d/%m/%Y'))

# %%
data2.fecha_ultimo_avo=data2.fecha_ultimo_avo.apply(lambda x: pd.to_datetime(x, format='%d/%m/%Y'))

# %%
data2.fecha_estado_tramite=data2.fecha_estado_tramite.apply(lambda x: pd.to_datetime(x, format='%d/%m/%Y'))

# %%
data2.fecha_estado_tramite=data2.fecha_estado_tramite.dt.date

# %%
data2['expediente']=data2['expediente'].str.replace('.', '')

# %%
data2.codigo_postal=pd.Series(data2.codigo_postal.values.astype(int))

# %%
data2.tipo_obra=data2.tipo_obra.replace(r'^\s+$', np.nan, regex=True)

# %%
data2
# Out:
#                             calle  calle_nro  seccion manzana parcela  \
# 0           ALVEAR, MARCELO T. DE       1325        7     040     019
# 1                     VERDI, JOSE       1762       87    001B    008
# 2                          THAMES        326       47    158     022
# 3                    SAN JUAN AV.       1874       22    065A    008
# 4         FLORES, VENANCIO, GRAL.       2925       65    022     022A
# 5                            POLA        569       60    022     024
# 6              GARAY, JUAN DE AV.       3225       30    032     021
# 7              GARAY, JUAN DE AV.       3225       30    032     021
# 8                  LINIERS VIRREY        782       28    018     020
# 9      FALCON, RAMON L.,CNEL. AV.       5958       60    053     002H
# 10                        QUEVEDO       3223       87     054     020
# 11                         THAMES       2450       19    173     020B
# ...

# %%
data2.to_csv('obras-iniciadas-20181106.csv', index=False)

# %%
datasubir=pd.read_csv('obras-iniciadas-20181106.csv')

# %%
datasubir.columns=['calle', 'calle_nro', 'seccion', 'manzana', 'parcela', 'expediente',
       'fecha_inicio_obra', 'estado', 'ultimo_avo_solicitado',
       'fecha_ultimo_avo', 'estado_tramite', 'profesional', 'barrio',
       'metros_a_construir', 'fecha_estado_tramite', 'tipo_obra', 'destino',
       'long', 'lat', 'comuna', 'codigo_postal', 'codigo_postal_argentino',
       'barrio1']

# %%
datasubir.columns
# Out:
# Index(['calle', 'calle_nro', 'seccion', 'manzana', 'parcela', 'expediente',
#        'fecha_inicio_obra', 'estado', 'ultimo_avo_solicitado',
#        'fecha_ultimo_avo', 'estado_tramite', 'profesional', 'barrio',
#        'metros_a_construir', 'fecha_estado_tramite', 'tipo_obra', 'destino',
#        'long', 'lat', 'comuna', 'codigo_postal', 'codigo_postal_argentino',
#        'barrio1'],
#       dtype='object')

# %% [markdown]
# ## Acá se esta subiendo una columna de barrio como NA, arreglar.

# %%
datasubir=datasubir[['long', 'lat','expediente', 'calle', 'calle_nro', 'seccion', 'manzana', 'parcela', 
       'fecha_inicio_obra', 'estado', 'ultimo_avo_solicitado',
       'fecha_ultimo_avo', 'estado_tramite', 'profesional',
       'metros_a_construir', 'fecha_estado_tramite', 'tipo_obra', 'destino', 'barrio1', 
        'comuna', 'codigo_postal', 'codigo_postal_argentino']]

# %%
datasubir.columns=['long', 'lat','expediente', 'calle', 'calle_nro', 'seccion', 'manzana', 'parcela', 
       'fecha_inicio_obra', 'estado', 'ultimo_avo_solicitado',
       'fecha_ultimo_avo', 'estado_tramite', 'profesional',
       'metros_a_construir', 'fecha_estado_tramite', 'tipo_obra', 'destino', 'barrio', 
        'comuna', 'codigo_postal', 'codigo_postal_argentino']

# %%
#carga de octubre no tiene falla de caracteres
# se cambio Ã por Í
#SE CAMBIO Ã‰ POR É
#Ãš por Ú
#Ã POR Á
#Â´ por '
#HUMBERTO 1Â° por humberto 1º
#Nu\u00f1ez por Nuñez

# %%
datasubir['metros_a_construir']=data2['metros_a_construir'].str.replace(',', '.')

# %%
datasubir['periodo']='201810'

# %%
datasubir=datasubir[['periodo', 'long', 'lat', 'expediente', 'calle', 'calle_nro', 'seccion', 'manzana',
       'parcela', 'fecha_inicio_obra', 'estado', 'ultimo_avo_solicitado',
       'fecha_ultimo_avo', 'estado_tramite', 'profesional',
       'metros_a_construir', 'fecha_estado_tramite', 'tipo_obra', 'destino',
       'barrio', 'comuna', 'codigo_postal', 'codigo_postal_argentino']]

# %%
datasubir['calle_nro']=datasubir['calle_nro'].fillna(0).astype(int)

# %%
datasubir['calle_nro']=datasubir['calle_nro'].astype(str).replace('0', '')

# %%
datasubir.to_csv('obras-iniciadas-20181106.csv', index=False)

# %% [markdown]
# ## Historico

# %%
dataportal=pd.read_csv('obras-iniciadas-portaloct.csv')

# %%
dataportal=dataportal[['periodo', 'long', 'lat', 'expediente', 'calle', 'calle_nro', 'seccion', 'manzana',
       'parcela', 'fecha_inicio_obra', 'estado', 'ultimo_avo_solicitado',
       'fecha_ultimo_avo', 'estado_tramite', 'profesional',
       'metros_a_construir', 'fecha_estado_tramite', 'tipo_obra', 'destino',
       'barrio', 'comuna', 'codigo_postal', 'codigo_postal_argentino']]

# %%
datahist=pd.concat([dataportal,datasubir], axis=0)

# %%
datahist=datahist.reset_index(drop=True)

# %%
datahist['calle_nro']=datahist['calle_nro'].fillna(0).astype(int)

# %%
datahist['calle_nro']=datahist['calle_nro'].astype(str).replace('0', '')

# %%
datahist
# Out:
#       periodo       long        lat     expediente  \
# 0      201808 -58.386029 -34.596947    100057/2015
# 1      201808 -58.511713 -34.623236  29423877/2017
# 2      201808 -58.445451 -34.596964   1659087/2011
# 3      201808 -58.392494 -34.622874  21777118/2015
# 4      201808 -58.507663 -34.644267  30400251/2017
# 5      201808 -58.410394 -34.629922  21605908/2017
# 6      201808 -58.413791 -34.620517  20894139/2017
# 7      201808 -58.510447 -34.640233    15397110/14
# 8      201808 -58.516921 -34.612946   6316498/2015
# 9      201808 -58.422431 -34.581687  13978948/2017
# 10     201808 -58.432934 -34.570724   6888043/2013
# 11     201808 -58.391466 -34.648356  17994842/2017
# 12     201808 -58.391466 -34.648356  17994842/2017
# 13     201808 -58.507030 -34.646346  21718495/2015
# 14     201808 -58.460895 -34.618969  27910125/2016
# 15     201808 -58.509856 -34.589725  25885366/2015
# 16     201808 -58.478217 -34.542923   5289542/2017
# ...

# %%
datahist.to_csv('obras-iniciadas-historico-20181106.csv', index=False)
