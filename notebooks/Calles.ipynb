# %%
import pandas as pd
import numpy as np
import re
import requests

# %%
data=pd.read_csv('callejero.csv')

# %%
data.shape
# Out:
# (30271, 30)

# %%
data.columns
# Out:
# Index(['WKT', 'id', 'codigo', 'nomoficial', 'alt_izqini', 'alt_izqfin',
#        'alt_derini', 'alt_derfin', 'nomanter', 'nom_mapa', 'tipo_c', 'long',
#        'sentido', 'cod_sent', 'observa', 'bicisenda', 'lado_ciclo',
#        'recorrid_x', 'ciclo_obse', 'tooltip_bi', 'red_jerarq', 'red_tp',
#        'ffcc', 'tipo_ffcc', 'COMUNA', 'COM_PAR', 'COM_IMPAR', 'BARRIO',
#        'BARRIO_PAR', 'BARRIO_IMP'],
#       dtype='object')

# %%
data.columns=['WKT', 'id', 'codigo', 'nomoficial', 'alt_izqini', 'alt_izqfin',
       'alt_derini', 'alt_derfin', 'nomanter', 'nom_mapa', 'tipo_c', 'long',
       'sentido', 'cod_sent', 'observa', 'bicisenda', 'lado_ciclo',
       'recorrid_x', 'ciclo_obse', 'tooltip_bi', 'red_jerarq', 'red_tp',
       'ffcc', 'tipo_ffcc', 'comuna', 'com_par', 'com_impar', 'barrio',
       'barrio_par', 'barrio_imp']

# %%
data
# Out:
#                                                      WKT     id  codigo  \
# 0      LINESTRING (-58.4693950261311 -34.590823162817...  28686   17138
# 1      LINESTRING (-58.4292181631792 -34.550847051085...    896   16003
# 2      LINESTRING (-58.4111723965244 -34.557682324602...   1724   16003
# 3      LINESTRING (-58.4843475765456 -34.557679517365...   1729   19028
# 4      LINESTRING (-58.4097807451194 -34.558784800912...   1828   16003
# 5      LINESTRING (-58.4809938700341 -34.560479478034...   1997   21059
# 6      LINESTRING (-58.4688924630455 -34.561179802456...   2062   19053
# 7      LINESTRING (-58.4542303649217 -34.569617237753...   3137   16011
# 8      LINESTRING (-58.4188285540955 -34.574702392892...   3831    4010
# 9      LINESTRING (-58.3895140539492 -34.574217897731...  30056   16003
# 10     LINESTRING (-58.4205865857438 -34.580793986215...   4846   20075
# 11     LINESTRING (-58.5130250274855 -34.581143587149...   4968    3210
# ...

# %%
count_nan = len(data) - data.count()
count_nan
# Out:
# WKT               0
# id                0
# codigo            0
# nomoficial        0
# alt_izqini        0
# alt_izqfin        0
# alt_derini        0
# alt_derfin        0
# nomanter      18274
# nom_mapa         33
# tipo_c            0
# long              0
# sentido           0
# cod_sent          0
# observa       23766
# bicisenda         0
# lado_ciclo    29781
# recorrid_x    30092
# ciclo_obse    28342
# tooltip_bi    27283
# red_jerarq        0
# red_tp        28319
# ffcc          29933
# tipo_ffcc     29933
# comuna            0
# com_par           0
# com_impar         0
# barrio         1687
# barrio_par       65
# barrio_imp       65
# dtype: int64

# %%
data.to_csv('callejero-040918.csv', index=False)
