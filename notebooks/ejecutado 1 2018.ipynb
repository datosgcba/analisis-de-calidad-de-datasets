# %%
import pandas as pd

# %%
data= pd.read_csv('2018-Tercer Trimestre.csv', sep=",")

# %%
data2= pd.read_csv('presupuesto-ejecutado-2018-segundo-trimestre.csv', sep=",")

# %%
data.shape
# Out:
# (52053, 44)

# %%
data2.shape
# Out:
# (48801, 44)

# %%
data.columns
# Out:
# Index(['Car', 'Car_desc', 'Jur', 'Jur_desc', 'Sjur', 'Sjur_ desc', 'Ent',
#        'Ent_desc', 'Og', 'og_desc', 'UE', 'UE_desc', 'Prog', 'Prog_desc',
#        'Sprog', 'Sprog_desc', 'Proy', 'Proy_desc', 'Act', 'Act_desc', 'Ob',
#        'Ob_desc', 'Fin', 'Fin_desc', 'Fun', 'Fun_desc', 'Inc', 'Inc_desc',
#        'Ppal', 'Ppal_desc', 'Par', 'Par_desc', 'Spar', 'Spar_desc', 'Eco',
#        'Eco_desc', 'Fte', 'Fte_desc', 'Geo', 'Geo_desc', 'Sanción', 'Vigente',
#        'Definitivo', 'Devengado'],
#       dtype='object')

# %%
data2.columns
# Out:
# Index(['Car', 'Car_desc', 'Jur', 'Jur_desc', 'Sjur', 'Sjur_desc', 'Ent',
#        'Ent_desc', 'Og', 'Og_desc', 'UE', 'UE_desc', 'Prog', 'Prog_desc',
#        'Sprog', 'Sprog_desc', 'Proy', 'Proy_desc', 'Actividad', 'Act_desc',
#        'Ob', 'ob_desc', 'Fin', 'Fin_desc', 'Fun', 'Fun_desc', 'Inc',
#        'Inc_desc', 'Ppal', 'Ppal_desc', 'Par', 'Par_desc', 'Spar', 'Spar_desc',
#        'Eco', 'Eco_desc', 'Fte', 'Fte_desc', 'Geo', 'Geo_desc', 'Sanción',
#        'Vigente', 'Definitivo', 'Devengado'],
#       dtype='object')

# %%
data.columns  = [                   'car', 'car_desc', 'jur', 'jur_desc', 'sjur', 'sjur_desc', 'ent',
       'ent_desc', 'og', 'eg_desc', 'ue', 'ue_desc', 'prog', 'prog_desc',
       'sprog', 'sprog_desc', 'proy', 'proy_desc', 'actividad', 'act_desc',
       'ob', 'ob_desc', 'fin', 'fin_desc', 'fun', 'fun_desc', 'inc',
       'inc_desc', 'ppal', 'ppal_desc', 'par', 'par_desc', 'spar', 'spar_desc',
       'eco', 'eco_desc', 'fte', 'fte_desc', 'geo', 'geo_desc', 'sancion',
       'vigente', 'definitivo', 'devengado']

# %%
count_nan = len(data) - data.count()

# %%
count_nan
# Out:
# car           0
# car_desc      0
# jur           0
# jur_desc      0
# sjur          0
# sjur_desc     0
# ent           0
# ent_desc      0
# og            0
# eg_desc       0
# ue            0
# ue_desc       0
# prog          0
# prog_desc     0
# sprog         0
# sprog_desc    0
# proy          0
# proy_desc     0
# actividad     0
# act_desc      0
# ob            0
# ob_desc       0
# fin           0
# fin_desc      0
# fun           0
# fun_desc      0
# inc           0
# inc_desc      0
# ppal          0
# ppal_desc     0
# par           0
# par_desc      0
# spar          0
# spar_desc     0
# eco           0
# eco_desc      0
# fte           0
# fte_desc      0
# geo           0
# geo_desc      0
# sancion       0
# vigente       0
# definitivo    0
# devengado     0
# dtype: int64

# %%
data
# Out:
#        car                     car_desc  jur  \
# 0        1       Administracion Central    1
# 1        1       Administracion Central    1
# 2        1       Administracion Central    1
# 3        1       Administracion Central    1
# 4        1       Administracion Central    1
# 5        1       Administracion Central    1
# 6        1       Administracion Central    1
# 7        1       Administracion Central    1
# 8        1       Administracion Central    1
# 9        1       Administracion Central    1
# 10       1       Administracion Central    1
# 11       1       Administracion Central    1
# 12       1       Administracion Central    1
# 13       1       Administracion Central    1
# 14       1       Administracion Central    1
# 15       1       Administracion Central    1
# 16       1       Administracion Central    1
# 17       1       Administracion Central    1
# 18       1       Administracion Central    1
# 19       1       Administracion Central    1
# ...

# %%
data.to_csv("presupuesto-ejecutado-2018-tercer-trimestre.csv", index=False)

# %% [markdown]
# # Presupuesto ejecutado 4to trimestre 2017

# %%
data4trim2017=pd.read_csv('2017-Cuarto Trimestre CI.csv')

# %%
dataport4trim17=pd.read_csv('presupuesto-ejecutado-2017-cuarto-trimestre.csv', sep=';')

# %%
count_nan = len(data4trim2017) - data4trim2017.count()
count_nan
# Out:
# Car           0
# Car_desc      0
# Jur           0
# Jur_desc      0
# Sjur          0
# SJur_desc     0
# Ent           0
# Ent_desc      0
# Og            0
# Og_desc       0
# UE            0
# UE_desc       0
# Prog          0
# Prog_desc     0
# Sprog         0
# Sprog_desc    0
# Proy          0
# Proy_desc     0
# Act           0
# Act_desc      0
# Obra          0
# ob_desc       0
# Fin           0
# Fin_desc      0
# Fun           0
# Fun_desc      0
# Inc           0
# Inc_desc      0
# Ppal          0
# Ppal_desc     0
# Par           0
# Par_desc      0
# Spar          0
# Spar_desc     0
# Eco           0
# Eco_desc      0
# Fte           0
# Fte_desc      0
# Geo           0
# Geo_desc      0
# Sanción       0
# Vigente       0
# Definitivo    0
# Devengado     0
# dtype: int64

# %%
data4trim2017.columns=['car', 'car_desc', 'jur', 'jur_desc', 'sjur', 'sjur_desc', 'ent',
       'ent_desc', 'og', 'og_desc', 'UE', 'UE_desc', 'prog', 'prog_desc',
       'sprog', 'sprog_desc', 'proy', 'proy_desc', 'act', 'act_desc', 'obra',
       'ob_desc', 'fin', 'fin_desc', 'fun', 'fun_desc', 'inc', 'inc_desc',
       'ppal', 'ppal_desc', 'par', 'par_desc', 'spar', 'spar_desc', 'eco',
       'eco_desc', 'fte', 'fte_desc', 'geo', 'geo_desc', 'sanción', 'vigente',
       'definitivo', 'devengado']

# %%
dataport4trim17.columns
# Out:
# Index(['CAR', 'CAR_DESC', 'JUR', 'JUR_DESC', 'SJUR', 'SJUR_DESC', 'ENT',
#        'ENT_DESC', 'OGESE', 'OGESE_DESC', 'UE', 'UE_DESC', 'PROG', 'PROG_DESC',
#        'SPROG', 'SPROG_DESC', 'PROY', 'PROY_DESC', 'ACT', 'ACT_DESC', 'OBRA',
#        'OBRA_DESC', 'FIN', 'FIN_DESC', 'FUN', 'FUN_DESC', 'INCISO',
#        'INCISO_DESC', 'PPAL', 'PPAL_DESC', 'PARC', 'PARC_DESC', 'SPARC',
#        'SPARC_DESC', 'ECO', 'ECO_DESC', 'FF', 'FF_DESC', 'GEO', 'GEO_DESC',
#        'SANCION', 'VIGENTE', 'DEFINITIVO', 'DEVENGADO'],
#       dtype='object')

# %%
data4trim2017.to_csv("presupuesto-ejecutado-cuartotrim2017.csv", index=False)
