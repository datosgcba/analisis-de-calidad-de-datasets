# %%
import pandas as pd
import numpy as np
import re
import requests

# %% [markdown]
# ## Acompañantes autorizados de Servicios escolares

# %%
data=pd.read_excel('Acompañantes de Transporte Escolar vigentes.xls')

# %%
data.columns=['numero', 'fecha_vto', 'apellido_y_nombre', 'numero_documento', 'domicilio_legal', 'papel_de_seguridad']

# %%
data['fecha_vto']= pd.to_datetime(data.fecha_vto, yearfirst=True)

# %%
lista_domicilio=data.domicilio_legal.astype(str)

# %%
lista_direcciones=[]
for i in lista_domicilio:
    lista_direcciones.append((i.replace('.','')))

# %%
data.domicilio_legal=lista_direcciones
data
# Out:
#     numero  fecha_vto                 apellido_y_nombre  numero_documento  \
# 0    A0001 2018-12-31                ALÉ SILVIA ADRIANA          17198487
# 1    A0002        NaT                    FRIAS CLOTILDE           4607581
# 2    A0003        NaT           FILANDINO CLARA NATALIA          28752472
# 3    A0004        NaT              ANDRÉS MYRIAM ROXANA          18213839
# 4    A0005        NaT                  BARRAGÁN VIVIANA          31576339
# 5    A0006 2019-01-31              MOLINAS MIRIAM MABEL          16582293
# 6    A0007        NaT           POITEVIN ALICIA BEATRIZ          21781919
# 7    A0008        NaT                 SUAREZ HEBE EDITH          18398584
# 8    A0009 2016-02-19        POITEVIN MARTA DEL ROSARIO          14946632
# 9    A0010        NaT             FERRERO BERTA MATILDE           4996292
# 10   A0011 2017-12-31               LONGO CLAUDIA CELIA          21465145
# 11   A0012        NaT            MORANI  NOELIA MARCELA          28860828
# ...

# %%
data['CABA']=data.domicilio_legal.str.extract('(CABA)', expand=True)
lista_vacia=[]
for i in data.domicilio_legal:
    lista_vacia.append(i.replace(' CABA', ''))

    
data.domicilio_legal=lista_vacia

# %%
data['fecha_vto']= pd.to_datetime(data.fecha_vto, yearfirst=True)

lista_domicilio=data.domicilio_legal.astype(str)

lista_direcciones=[]
for i in lista_domicilio:
    lista_direcciones.append((i.replace('.',''))) 


data.domicilio_legal=lista_direcciones
data

data['CABA']=data.domicilio_legal.str.extract('(CABA)', expand=True)
lista_vacia=[]
for i in data.domicilio_legal:
    lista_vacia.append(i.replace(' CABA', ''))

    
data.domicilio_legal=lista_vacia

# %%
data
# Out:
#     numero  fecha_vto                 apellido_y_nombre  numero_documento  \
# 0    A0001 2018-12-31                ALÉ SILVIA ADRIANA          17198487
# 1    A0002        NaT                    FRIAS CLOTILDE           4607581
# 2    A0003        NaT           FILANDINO CLARA NATALIA          28752472
# 3    A0004        NaT              ANDRÉS MYRIAM ROXANA          18213839
# 4    A0005        NaT                  BARRAGÁN VIVIANA          31576339
# 5    A0006 2019-01-31              MOLINAS MIRIAM MABEL          16582293
# 6    A0007        NaT           POITEVIN ALICIA BEATRIZ          21781919
# 7    A0008        NaT                 SUAREZ HEBE EDITH          18398584
# 8    A0009 2016-02-19        POITEVIN MARTA DEL ROSARIO          14946632
# 9    A0010        NaT             FERRERO BERTA MATILDE           4996292
# 10   A0011 2017-12-31               LONGO CLAUDIA CELIA          21465145
# 11   A0012        NaT            MORANI  NOELIA MARCELA          28860828
# ...

# %%
data['piso_dpto']=data.domicilio_legal.str.extract('(\d+º.\w*|\d+ª.\w*|\d+º|\d+ª|PB.\d*|PB|Dto.1|Dto.2|Dto.A|Dto.B)', expand=True)

# %%
data.domicilio_legal.replace('(\d+º.\w*|\d+ª.\w*|\d+º|\d+ª|PB.\d*|PB|Dto.1|Dto.2|Dto.A|Dto.B)', '', inplace=True, regex=True)

# %%
data['DOMICILIO_URL_CABA']=data.domicilio_legal.str.extract('(\D+\d{1,5})',expand=True)

# %%
data['DOMICILIO_URL_CABA'].values
# Out:
# array(['CREL PEDRO GARCIA 5777', 'LUGANO 1', 'LACARRA 3550',
#        'VENTURA DE LA VEGA 3870', 'ISABEL LA CATOLICA 352', 'BOGOTA 924',
#        ' Nº 2326', 'AGUSTIN DE VEDIA 2964', 'ZAPIOLA 1383',
#        'BENITO JUAREZ 1974', 'MATHEU 1791', 'ANDALGALÁ 1135',
#        'RAFAELA 4414', ' DE ABRIL S/N Ed 41', 'OYHANARTE 285',
#        'CASTRO BARROS 1367', 'LINIERS 375', 'CAÑADA DE GOMEZ 4763',
#        'GOMEZ DE FONSECA 667', 'BERGANTIN NANCY 5248', 'TABARE 6822',
#        'ARGERICH 2565', 'BALCARCE 3671', 'AGÜERO Y Av CRUZ mob 26',
#        'JOSE TAMBORINI 5055', 'NAZARRE 5048', 'AGUSTIN DE VEDIA 2038',
#        'Pr AGÜERO  6219', ' 3382', 'BONORINO 934', 'NAZARRE 5048',
#        'JMPAZOS 6316', 'OLIDEN 72', nan, 'TANDIL 4658', 'ISLETA 1830',
#        'LACARRA 282', 'BOLIVIA 1082', 'MARCOS SASTRE 5380',
#        'AM CERVANTES 1926', 'AV NAZCA 1492', 'AV BELGRANO 2288',
#        'FELIPE VALLESE 968', 'M R TRELLES 2098', 'AV SANTA FE 5235',
# ...

# %%
SERIE_URL=[]
for i in data.DOMICILIO_URL_CABA.astype(str):
    SERIE_URL.append('http://servicios.usig.buenosaires.gob.ar/normalizar/?direccion='+i+',caba&geocodificar=TRUE')

# %%
def get_x(dir):
    try:
        response= requests.get(dir)
        pattern='"x":."(.\d+.\d+)"'
        
        if (re.findall(pattern, response.text)!=[]):
            x.append(re.findall(pattern, response.text)[0])
            print('.')
        else:
            x.append(np.nan)
            print( i )
    except:
        x.append(np.nan)
        print('sin URL'+ i)

# %%
x=[]
for i in SERIE_URL:
    get_x(i)
# Out:
# http://servicios.usig.buenosaires.gob.ar/normalizar/?direccion=CREL PEDRO GARCIA 5777,caba&geocodificar=TRUE
# http://servicios.usig.buenosaires.gob.ar/normalizar/?direccion=LUGANO 1,caba&geocodificar=TRUE
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# http://servicios.usig.buenosaires.gob.ar/normalizar/?direccion= DE ABRIL S/N Ed 41,caba&geocodificar=TRUE
# http://servicios.usig.buenosaires.gob.ar/normalizar/?direccion=OYHANARTE 285,caba&geocodificar=TRUE
# .
# .
# .
# .
# .
# .
# .
# http://servicios.usig.buenosaires.gob.ar/normalizar/?direccion=BALCARCE 3671,caba&geocodificar=TRUE
# http://servicios.usig.buenosaires.gob.ar/normalizar/?direccion=AGÜERO Y Av CRUZ mob 26,caba&geocodificar=TRUE
# .
# .
# .
# http://servicios.usig.buenosaires.gob.ar/normalizar/?direccion=Pr AGÜERO  6219,caba&geocodificar=TRUE
# http://servicios.usig.buenosaires.gob.ar/normalizar/?direccion= 3382,caba&geocodificar=TRUE
# .
# .
# ...

# %%
def get_lat(url):
    try:
        response= requests.get(url)
        pattern='"y":."(.*?)"'
        if (re.findall(pattern, response.text)!=[]):
                lat.append(re.findall(pattern, response.text)[0])
                print('.')
        else:
            lat.append(np.nan)
            print( i )
       
    except:
        lat.append(np.nan)
        print('sin URL')

# %%
lat=[]
for i in SERIE_URL:
    get_lat(i)
# Out:
# http://servicios.usig.buenosaires.gob.ar/normalizar/?direccion=CREL PEDRO GARCIA 5777,caba&geocodificar=TRUE
# http://servicios.usig.buenosaires.gob.ar/normalizar/?direccion=LUGANO 1,caba&geocodificar=TRUE
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# http://servicios.usig.buenosaires.gob.ar/normalizar/?direccion= DE ABRIL S/N Ed 41,caba&geocodificar=TRUE
# http://servicios.usig.buenosaires.gob.ar/normalizar/?direccion=OYHANARTE 285,caba&geocodificar=TRUE
# .
# .
# .
# .
# .
# .
# .
# http://servicios.usig.buenosaires.gob.ar/normalizar/?direccion=BALCARCE 3671,caba&geocodificar=TRUE
# http://servicios.usig.buenosaires.gob.ar/normalizar/?direccion=AGÜERO Y Av CRUZ mob 26,caba&geocodificar=TRUE
# .
# .
# .
# http://servicios.usig.buenosaires.gob.ar/normalizar/?direccion=Pr AGÜERO  6219,caba&geocodificar=TRUE
# http://servicios.usig.buenosaires.gob.ar/normalizar/?direccion= 3382,caba&geocodificar=TRUE
# .
# .
# ...

# %%
def get_calle(url):
    try:
        response= requests.get(url)
        pattern='"nombre_calle":."(.*?)"'
        if (re.findall(pattern, response.text)!=[]):
                calle.append(re.findall(pattern, response.text)[0])
                print('.')
        else:
            calle.append(np.nan)
            print('sin calle')
    except:
        calle.append(np.nan)
        print('sin URL')

# %%
calle=[]
for i in SERIE_URL:
    get_calle(i)
    print
# Out:
# sin calle
# sin calle
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# sin calle
# sin calle
# .
# .
# .
# .
# .
# .
# .
# sin calle
# sin calle
# .
# .
# .
# sin calle
# sin calle
# .
# .
# sin calle
# .
# .
# .
# sin calle
# .
# .
# .
# sin calle
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# sin calle
# .
# .
# .
# .
# .
# .
# .
# .
# sin calle
# .
# .
# .
# .
# sin calle
# .
# .
# sin calle
# .
# .
# .
# .
# .
# .
# .
# sin calle
# sin calle
# .
# .
# sin calle
# .
# .
# .
# .
# sin calle
# .
# .
# .
# .
# .
# .
# sin calle
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# sin calle
# sin calle
# sin calle
# sin calle
# sin calle
# sin calle
# sin calle
# sin calle
# sin calle
# sin calle
# sin calle
# .
# .
# .
# sin calle
# sin calle
# .
# .
# .
# .
# .
# .
# sin calle
# .
# .
# .
# .
# sin calle
# .
# .
# .
# .
# .
# .
# sin calle
# .
# .
# .
# .
# .
# .
# sin calle
# sin calle
# sin calle
# sin calle
# sin calle
# sin calle
# sin calle
# .
# sin calle
# .
# .
# ...

# %%
calle
# Out:
# [nan,
#  nan,
#  'LACARRA AV.',
#  'VEGA, VENTURA DE LA',
#  'ISABEL LA CATOLICA',
#  'BOGOTA',
#  'NAON, ROMULO',
#  'VEDIA, AGUSTIN DE',
#  'ZAPIOLA',
#  'JUAREZ, BENITO',
#  'MATHEU',
#  'ANDALGALA',
#  'RAFAELA',
#  nan,
#  nan,
#  'CASTRO BARROS',
#  'LINIERS VIRREY',
#  'CA\\u00d1ADA DE GOMEZ',
#  'GOMEZ DE FONSECA',
#  'BERGANTIN NANCY',
#  'TABARE',
#  'ARGERICH',
#  nan,
#  nan,
#  'TAMBORINI, JOSE PASCUAL',
#  'NAZARRE',
#  'VEDIA, AGUSTIN DE',
#  nan,
#  nan,
#  'BONORINO, ESTEBAN, CNEL. AV.',
#  'NAZARRE',
#  nan,
#  'OLIDEN',
#  'BERGANTIN NANCY',
#  'TANDIL',
#  nan,
#  'LACARRA',
#  'ESTADO PLURINACIONAL DE BOLIVIA',
#  'SASTRE, MARCOS',
#  nan,
#  'NAZCA AV.',
#  'BELGRANO AV.',
#  'VALLESE, FELIPE',
#  'TRELLES, MANUEL R.',
#  'SANTA FE AV.',
#  'DEAN FUNES',
#  'ESTADO PLURINACIONAL DE BOLIVIA',
#  'HABANA',
#  'JUAREZ, BENITO',
#  'NAZARRE',
#  nan,
#  'MORENO, JOSE MARIA AV.',
#  'SANTANDER',
#  'MOZART',
#  'RIVERA, FRUCTUOSO, GENERAL',
#  'SERRANO',
#  'ROJAS',
# ...

# %%
def get_altura(url):
    try:
        response= requests.get(url)
        pattern='"altura":.(\d+)'
        if (re.findall(pattern, response.text)!=[]):
                altura.append(re.findall(pattern, response.text)[0])
                print('.')
        else:
            altura.append(np.nan)
            print('sin altura') 
    except:
        altura.append(np.nan)
        print('sin URL')

# %%
altura=[]
for i in SERIE_URL:
    get_altura(i)
    print
# Out:
# sin altura
# sin altura
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# sin altura
# sin altura
# .
# .
# .
# .
# .
# .
# .
# sin altura
# sin altura
# .
# .
# .
# sin altura
# sin altura
# .
# .
# sin altura
# .
# sin altura
# .
# sin altura
# .
# .
# .
# sin altura
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# sin altura
# .
# .
# .
# .
# .
# .
# .
# .
# sin altura
# .
# .
# .
# sin altura
# sin altura
# .
# .
# sin altura
# .
# .
# .
# .
# .
# .
# .
# sin altura
# sin altura
# .
# .
# sin altura
# .
# .
# .
# .
# sin altura
# .
# .
# .
# .
# .
# .
# sin altura
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# sin altura
# sin altura
# sin altura
# sin altura
# sin altura
# sin altura
# sin altura
# sin altura
# sin altura
# sin altura
# sin altura
# .
# .
# .
# sin altura
# sin altura
# .
# .
# .
# .
# .
# .
# sin altura
# .
# .
# .
# .
# sin altura
# .
# .
# .
# .
# .
# .
# sin altura
# .
# .
# .
# .
# .
# .
# sin altura
# sin altura
# sin altura
# sin altura
# ...

# %%
altura=pd.Series(altura)
calle=pd.Series(calle)

# %%
data=pd.concat([data,calle,altura], axis=1)

# %%
data.columns=[            'numero',          'fecha_vto',  'apellido_y_nombre',
         'numero_documento',    'domicilio_legal', 'papel_de_seguridad',
                     'CABA',          'piso_dpto', 'DOMICILIO_URL_CABA',
                          'calle',                    'altura']

# %%
datos_utiles_url=[]
for i in data['calle']:
    try:
        datos_utiles_url.append('http://ws.usig.buenosaires.gob.ar/datos_utiles/?callback=?&calle='+i+'&altura=')
    except:
        datos_utiles_url.append(np.nan)
        print('es un nan')
# Out:
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# ...

# %%
datos_utiles_url_=pd.Series(datos_utiles_url)+data['altura'].astype(str)

# %%
altura_url=data['altura'].values.astype(str)

# %%
def get_comuna(url):
    try:
        response= requests.get(url)
        pattern='"comuna":"(Comuna.\d+)"'
        if response.status_code == 200:
            comuna.append(re.findall(pattern, response.text)[0])
            print('.')

        return comuna
    except:
        print(url)
        comuna.append(np.nan)

# %%
comuna=[]
for i in datos_utiles_url_:
    get_comuna(i)
# Out:
# nan
# nan
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# nan
# nan
# .
# .
# http://ws.usig.buenosaires.gob.ar/datos_utiles/?callback=?&calle=CA\u00d1ADA DE GOMEZ&altura=4763
# .
# .
# .
# .
# nan
# nan
# .
# .
# .
# nan
# nan
# .
# .
# nan
# .
# http://ws.usig.buenosaires.gob.ar/datos_utiles/?callback=?&calle=BERGANTIN NANCY&altura=nan
# .
# nan
# .
# .
# .
# nan
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# nan
# .
# .
# .
# .
# .
# .
# .
# .
# nan
# .
# .
# .
# http://ws.usig.buenosaires.gob.ar/datos_utiles/?callback=?&calle=BERGANTIN NANCY&altura=nan
# nan
# .
# .
# nan
# .
# .
# .
# .
# .
# .
# .
# nan
# nan
# .
# .
# nan
# .
# .
# .
# http://ws.usig.buenosaires.gob.ar/datos_utiles/?callback=?&calle=PE\u00d1A&altura=2215
# nan
# .
# .
# .
# .
# .
# .
# nan
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# http://ws.usig.buenosaires.gob.ar/datos_utiles/?callback=?&calle=CA\u00d1ADA DE GOMEZ&altura=1426
# ...

# %%
def get_barrio(url):
    try:
        response= requests.get(url)
        pattern='"barrio":"(.*?)"'
        if response.status_code == 200:
            barrio.append(re.findall(pattern, response.text)[0])
            print('.')


        return barrio
    except:
        print('XXXX')
        barrio.append(np.nan)

# %%
barrio=[]
for i in datos_utiles_url_:
    get_barrio(i)
# Out:
# XXXX
# XXXX
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# XXXX
# XXXX
# .
# .
# XXXX
# .
# .
# .
# .
# XXXX
# XXXX
# .
# .
# .
# XXXX
# XXXX
# .
# .
# XXXX
# .
# XXXX
# .
# XXXX
# .
# .
# .
# XXXX
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# XXXX
# .
# .
# .
# .
# .
# .
# .
# .
# XXXX
# .
# .
# .
# XXXX
# XXXX
# .
# .
# XXXX
# .
# .
# .
# .
# .
# .
# .
# XXXX
# XXXX
# .
# .
# XXXX
# .
# .
# .
# XXXX
# XXXX
# .
# .
# .
# .
# .
# .
# XXXX
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# XXXX
# XXXX
# XXXX
# XXXX
# XXXX
# XXXX
# XXXX
# XXXX
# XXXX
# XXXX
# XXXX
# XXXX
# .
# .
# XXXX
# XXXX
# .
# .
# .
# .
# .
# .
# XXXX
# .
# .
# .
# .
# XXXX
# .
# .
# .
# .
# .
# .
# XXXX
# .
# .
# .
# .
# .
# .
# XXXX
# XXXX
# XXXX
# XXXX
# XXXX
# XXXX
# XXXX
# .
# XXXX
# .
# XXXX
# XXXX
# .
# XXXX
# XXXX
# XXXX
# .
# .
# .
# .
# XXXX
# XXXX
# XXXX
# XXXX
# XXXX
# XXXX
# XXXX
# XXXX
# XXXX
# XXXX
# XXXX
# .
# XXXX
# XXXX
# XXXX
# XXXX
# XXXX
# XXXX
# XXXX
# XXXX
# .
# .
# .
# .
# .
# .
# ...

# %%
def get_cp(url):
    try:
        response= requests.get(url)
        pattern='"codigo_postal":"(.*?)"'
        if response.status_code == 200:
            cp.append(re.findall(pattern, response.text)[0])
            print('.')

        return cp
    except:
        print('XXXX')
        cp.append(np.nan)

# %%
cp=[]
for i in datos_utiles_url_:
    get_cp(i)
# Out:
# XXXX
# XXXX
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# XXXX
# XXXX
# .
# .
# XXXX
# .
# .
# .
# .
# XXXX
# XXXX
# .
# .
# .
# XXXX
# XXXX
# .
# .
# XXXX
# .
# XXXX
# .
# XXXX
# .
# .
# .
# XXXX
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# XXXX
# .
# .
# .
# .
# .
# .
# .
# .
# XXXX
# .
# .
# .
# XXXX
# XXXX
# .
# .
# XXXX
# .
# .
# .
# .
# .
# .
# .
# XXXX
# XXXX
# .
# .
# XXXX
# .
# .
# .
# XXXX
# XXXX
# .
# .
# .
# .
# .
# .
# XXXX
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# XXXX
# XXXX
# XXXX
# XXXX
# XXXX
# XXXX
# XXXX
# XXXX
# XXXX
# XXXX
# XXXX
# XXXX
# .
# .
# XXXX
# XXXX
# .
# .
# .
# .
# .
# .
# XXXX
# .
# .
# .
# .
# XXXX
# .
# .
# .
# .
# .
# .
# XXXX
# .
# .
# .
# .
# .
# .
# XXXX
# XXXX
# XXXX
# XXXX
# XXXX
# XXXX
# XXXX
# .
# XXXX
# .
# XXXX
# XXXX
# .
# XXXX
# XXXX
# XXXX
# .
# .
# .
# .
# XXXX
# XXXX
# XXXX
# XXXX
# XXXX
# XXXX
# XXXX
# XXXX
# XXXX
# XXXX
# XXXX
# .
# XXXX
# XXXX
# XXXX
# XXXX
# XXXX
# XXXX
# XXXX
# XXXX
# .
# .
# .
# .
# .
# .
# ...

# %%
def get_cpa(url):
    try:
        response= requests.get(url)
        pattern='"codigo_postal_argentino":"(.*?)"'
        if response.status_code == 200:
            cpa.append(re.findall(pattern, response.text)[0])
            print('.')

        return cpa
    except:
        print('XXXX')
        cpa.append(np.nan)

# %%
cpa=[]
for i in datos_utiles_url_:
    get_cpa(i)
# Out:
# XXXX
# XXXX
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# XXXX
# XXXX
# .
# .
# XXXX
# .
# .
# .
# .
# XXXX
# XXXX
# .
# .
# .
# XXXX
# XXXX
# .
# .
# XXXX
# .
# XXXX
# .
# XXXX
# .
# .
# .
# XXXX
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# XXXX
# .
# .
# .
# .
# .
# .
# .
# .
# XXXX
# .
# .
# .
# XXXX
# XXXX
# .
# .
# XXXX
# .
# .
# .
# .
# .
# .
# .
# XXXX
# XXXX
# .
# .
# XXXX
# .
# .
# .
# XXXX
# XXXX
# .
# .
# .
# .
# .
# .
# XXXX
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# XXXX
# XXXX
# XXXX
# XXXX
# XXXX
# XXXX
# XXXX
# XXXX
# XXXX
# XXXX
# XXXX
# XXXX
# .
# .
# XXXX
# XXXX
# .
# .
# .
# .
# .
# .
# XXXX
# .
# .
# .
# .
# XXXX
# .
# .
# .
# .
# .
# .
# XXXX
# .
# .
# .
# .
# .
# .
# XXXX
# XXXX
# XXXX
# XXXX
# XXXX
# XXXX
# XXXX
# .
# XXXX
# .
# XXXX
# XXXX
# .
# XXXX
# XXXX
# XXXX
# .
# .
# .
# .
# XXXX
# XXXX
# XXXX
# XXXX
# XXXX
# XXXX
# XXXX
# XXXX
# XXXX
# XXXX
# XXXX
# .
# XXXX
# XXXX
# XXXX
# XXXX
# XXXX
# XXXX
# XXXX
# XXXX
# .
# .
# .
# .
# .
# .
# ...

# %%
x=pd.Series(x)
lat=pd.Series(lat)
barrio=pd.Series(barrio)
comuna=pd.Series(comuna)
cp=pd.Series(cp)
cpa=pd.Series(cpa)

# %%
data2=pd.concat([data,x,lat,barrio,comuna,cp,cpa], axis=1)

# %%
data2=data2[[0,1, 'numero', 'fecha_vto', 'apellido_y_nombre', 'numero_documento', 'domicilio_legal', 'piso_dpto', 'papel_de_seguridad', 2,3,4,5]]

# %%
data2.columns=[ 'long',                    'lat',             'numero',
                'fecha_vto',  'apellido_y_nombre',   'numero_documento',
          'domicilio_legal',          'piso_dpto', 'papel_de_seguridad',
                          'barrio',                    'comuna',                    'codigo_postal',
                          'codigo_postal_argentino']

# %%
data2
# Out:
#            long         lat numero  fecha_vto  \
# 0           NaN         NaN  A0001 2018-12-31
# 1           NaN         NaN  A0002        NaT
# 2    -58.445085  -34.668758  A0003        NaT
# 3    -58.414559  -34.653775  A0004        NaT
# 4    -58.373898  -34.635641  A0005        NaT
# 5    -58.444551  -34.618090  A0006 2019-01-31
# 6    -58.472296  -34.568041  A0007        NaT
# 7    -58.427545  -34.651895  A0008        NaT
# 8    -58.455749  -34.572117  A0009 2016-02-19
# 9    -58.503631  -34.621707  A0010        NaT
# 10   -58.398028  -34.630094  A0011 2017-12-31
# 11   -58.520631  -34.651435  A0012        NaT
# 12   -58.489156  -34.638450  A0013        NaT
# 13          NaN         NaN  A0014        NaT
# 14          NaN         NaN  A0015        NaT
# 15   -58.418190  -34.628839  A0016        NaT
# 16   -58.414452  -34.615288  A0017        NaT
# 17   -58.475448  -34.685007  A0018        NaT
# 18   -58.493015  -34.629510  A0019        NaT
# ...

# %%
data2.to_csv('acompañantes-autorizados-de-servicios-escolares.csv', index=False)

# %%
datah=pd.read_csv('registro-historico-acumulado-de-acompanantes-autorizados-de-servicios-escolares.csv', sep=';')

# %%
data2['periodo']='2018 SEPTIEMBRE'
# Out:
# C:\Users\rama_\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
data2=data2[['long', 'lat', 'periodo', 'numero', 'fecha_vto', 'apellido_y_nombre',
       'numero_documento', 'domicilio_legal', 'piso_dpto',
       'papel_de_seguridad', 'barrio', 'comuna', 'codigo_postal',
       'codigo_postal_argentino']]

# %%
datah['apellido_y_nombre']=datah.APELLIDO+' '+datah.NOMBRE

# %%
data2.columns
# Out:
# Index(['long', 'lat', 'periodo', 'numero', 'fecha_vto', 'apellido_y_nombre',
#        'numero_documento', 'domicilio_legal', 'piso_dpto',
#        'papel_de_seguridad', 'barrio', 'comuna', 'codigo_postal',
#        'codigo_postal_argentino'],
#       dtype='object')

# %%
datah.columns=['long', 'lat', 'periodo', 'numero', 'fecha_vto', 'apellido_y_nombre',
       'numero_documento', 'domicilio_legal', 'piso_dpto',
       'papel_de_seguridad', 'barrio', 'comuna', 'codigo_postal',
       'codigo_postal_argentino']

# %%
datah=datah[['LNG', 'LAT', 'PERIODO', 'NUMERO', 'FECHA_VTO', 'apellido_y_nombre','DNI', 'DOMICILIO_LEGAL', 'PISO_DPTO', 'PAPEL_DE_SEGURIDAD', 'BARRIO',
       'COMUNA', 'CODIGO_POSTAL', 'CODIGO_POSTAL_ARG']]

# %%
datah
# Out:
#               long            lat             periodo numero   fecha_vto  \
# 0              NaN            NaN   2016 JULIO-AGOSTO  A0336   24/6/2017
# 1                                   2016 JULIO-AGOSTO  A0334   24/6/2017
# 2    -58,480596710  -34,686069630     2016 MAYO-JUNIO  A0319  29/10/2016
# 3    -58,480596710  -34,686069630   2016 JULIO-AGOSTO  A0319  29/10/2016
# 4    -58,468100000  -34,683611620     2016 MAYO-JUNIO  A0001    4/1/2017
# 5    -58,468100000  -34,683611620   2016 JULIO-AGOSTO  A0001    4/1/2017
# 6    -58,474466560  -34,670554810     2016 MAYO-JUNIO  A0080   11/5/2016
# 7    -58,506778080  -34,662399130     2016 MAYO-JUNIO  A0094   11/5/2016
# 8    -58,506778080  -34,662399130   2016 JULIO-AGOSTO  A0094   17/5/2017
# 9    -58,465174220  -34,660729250   2016 JULIO-AGOSTO  A0335   24/6/2017
# 10   -58,515939820  -34,660015150     2016 MAYO-JUNIO  A0093   10/8/2016
# 11   -58,515939820  -34,660015150   2016 JULIO-AGOSTO  A0093   10/8/2016
# ...

# %%
datah['long']=datah['long'].str.replace(',', '.')
datah['lat']=datah['lat'].str.replace(',', '.')
# Out:
# C:\Users\rama_\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\rama_\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
datah['codigo_postal']=datah['codigo_postal'].fillna(0).astype(int)
# Out:
# C:\Users\rama_\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
datah.fecha_vto=datah.fecha_vto.apply(lambda x: pd.to_datetime(x, yearfirst=True))
# Out:
# C:\Users\rama_\Anaconda3\lib\site-packages\pandas\core\generic.py:4401: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value

# %%
datasubir=pd.concat([datah,data2], axis=0)

# %%
datasubir=datasubir.reset_index(drop=True)

# %%
datasubir['codigo_postal']=datasubir['codigo_postal'].astype(str).replace('0', '')

# %%
datasubir.to_csv('acompañantes-autorizados-de-pasajeros-historico-20181008.csv', index=False)

# %% [markdown]
# ## Conductores autorizados de Servicios Escolares

# %%
data=pd.read_excel('Conductores de Transporte Escolar vigentes_v2.xls', sheet_name='conductores')

# %%
data=data.iloc[:,0:9]

# %%
data
# Out:
#      numero            fecha_vto             apellido_y_nombre  \
# 0     C0001  2019-01-31 00:00:00           OTERO ESTELA ALICIA
# 1     C0002                  NaN        BRUSATORI MARÍA SUSANA
# 2     C0003  2019-03-31 00:00:00       BOYADJIAN FABIAN ARIEL
# 3     C0004  2019-01-31 00:00:00         DAVERIO OSCAR GABRIEL
# 4     C0005  2018-11-30 00:00:00          DAPARO MARTÍN ADRIAN
# 5     C0006  2019-09-30 00:00:00       DAPARO SALVADOR MIGUEL
# 6     C0007  2019-09-30 00:00:00         BERNAY BEATRIZ JOSEFA
# 7     C0008  2019-03-31 00:00:00                  RATIS MIGUEL
# 8     C0009  2019-01-31 00:00:00        FERRER JORGE GUILLERMO
# 9     C0010  2019-01-31 00:00:00          SANTOS ANTONIO RUBEN
# 10    C0011                  NaN           DIAZ OSCAR ALBERTO
# 11    C0012  2019-01-31 00:00:00          CHAIN ARACELI RAQUEL
# 12    C0013  2019-01-31 00:00:00            FILARDO JORGE JOSE
# 13    C0014                  NaN         SANTIAGO LUIS ALBERTO
# ...

# %%
data.columns=['numero', 'fecha_vto', 'apellido_y_nombre', 'numero_documento', 'titular_si/no', 'titular_de_licencia', 'domicilio_legal', 'dominio', 'papel_de_seguridad']

# %%
lista_domicilio=data.domicilio_legal.astype(str)

# %%
lista_direcciones=[]
for i in lista_domicilio:
    lista_direcciones.append((i.replace('.','')))

# %%
data.domicilio_legal=lista_direcciones
data
# Out:
# C:\Users\rama_\Anaconda3\lib\site-packages\pandas\core\generic.py:4401: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value
#      numero            fecha_vto             apellido_y_nombre  \
# 0     C0001  2019-01-31 00:00:00           OTERO ESTELA ALICIA
# 1     C0002                  NaN        BRUSATORI MARÍA SUSANA
# 2     C0003  2019-03-31 00:00:00       BOYADJIAN FABIAN ARIEL
# 3     C0004  2019-01-31 00:00:00         DAVERIO OSCAR GABRIEL
# 4     C0005  2018-11-30 00:00:00          DAPARO MARTÍN ADRIAN
# 5     C0006  2019-09-30 00:00:00       DAPARO SALVADOR MIGUEL
# 6     C0007  2019-09-30 00:00:00         BERNAY BEATRIZ JOSEFA
# 7     C0008  2019-03-31 00:00:00                  RATIS MIGUEL
# ...

# %%
data['CABA']=data.domicilio_legal.str.extract('(CABA)', expand=True)
lista_vacia=[]
for i in data.domicilio_legal:
    lista_vacia.append(i.replace(' CABA', ''))

    
data.domicilio_legal=lista_vacia

# %%
data
# Out:
#     numero  fecha_vto                 apellido_y_nombre  numero_documento  \
# 0    A0001 2018-12-31                ALÉ SILVIA ADRIANA          17198487
# 1    A0002        NaT                    FRIAS CLOTILDE           4607581
# 2    A0003        NaT           FILANDINO CLARA NATALIA          28752472
# 3    A0004        NaT              ANDRÉS MYRIAM ROXANA          18213839
# 4    A0005        NaT                  BARRAGÁN VIVIANA          31576339
# 5    A0006 2019-01-31              MOLINAS MIRIAM MABEL          16582293
# 6    A0007        NaT           POITEVIN ALICIA BEATRIZ          21781919
# 7    A0008        NaT                 SUAREZ HEBE EDITH          18398584
# 8    A0009 2016-02-19        POITEVIN MARTA DEL ROSARIO          14946632
# 9    A0010        NaT             FERRERO BERTA MATILDE           4996292
# 10   A0011 2017-12-31               LONGO CLAUDIA CELIA          21465145
# 11   A0012        NaT            MORANI  NOELIA MARCELA          28860828
# ...

# %%
data['piso_dpto']=data.domicilio_legal.str.extract('(\d+º.\w*|\d+ª.\w*|\d+º|\d+ª|PB.\d*|PB|Dto.1|Dto.2|Dto.A|Dto.B)', expand=True)

# %%
data.domicilio_legal.replace('(\d+º.\w*|\d+ª.\w*|\d+º|\d+ª|PB.\d*|PB|Dto.1|Dto.2|Dto.A|Dto.B)', '', inplace=True, regex=True)

# %%
data['DOMICILIO_URL_CABA']=data.domicilio_legal.str.extract('(\D+\d{1,5})',expand=True)

# %%
data['DOMICILIO_URL_CABA'].values
# Out:
# array(['MAGALLANES 1167', 'JOSE MARMOL 2130', 'DEAN FUNES 2182', ...,
#        'DIAZ COLODRERO 3432', 'FRENCH 2966', 'CARLOS ORTIZ 1178'],
#       dtype=object)

# %%
SERIE_URL=[]
for i in data.DOMICILIO_URL_CABA.astype(str):
    SERIE_URL.append('http://servicios.usig.buenosaires.gob.ar/normalizar/?direccion='+i+',caba&geocodificar=TRUE')

# %%
def get_x(dir):
    try:
        response= requests.get(dir)
        pattern='"x":."(.\d+.\d+)"'
        
        if (re.findall(pattern, response.text)!=[]):
            x.append(re.findall(pattern, response.text)[0])
            print('.')
        else:
            x.append(np.nan)
            print( i )
    except:
        x.append(np.nan)
        print('sin URL'+ i)

# %%
x=[]
for i in SERIE_URL:
    get_x(i)
# Out:
# .
# .
# .
# .
# .
# .
# .
# .
# .
# http://servicios.usig.buenosaires.gob.ar/normalizar/?direccion=STA MARIA DEL BUEN AYRE 871,caba&geocodificar=TRUE
# http://servicios.usig.buenosaires.gob.ar/normalizar/?direccion=GALVES 2275,caba&geocodificar=TRUE
# .
# http://servicios.usig.buenosaires.gob.ar/normalizar/?direccion=RL  FALCON 4981,caba&geocodificar=TRUE
# .
# .
# http://servicios.usig.buenosaires.gob.ar/normalizar/?direccion=CAAGUAZU 343,caba&geocodificar=TRUE
# .
# .
# .
# .
# .
# .
# .
# http://servicios.usig.buenosaires.gob.ar/normalizar/?direccion=OTAMANDI 464,caba&geocodificar=TRUE
# .
# http://servicios.usig.buenosaires.gob.ar/normalizar/?direccion=CNEL OLASCUAGA 5003,caba&geocodificar=TRUE
# .
# .
# .
# .
# .
# .
# http://servicios.usig.buenosaires.gob.ar/normalizar/?direccion=PIEDRA BUENA SEC C3,caba&geocodificar=TRUE
# .
# http://servicios.usig.buenosaires.gob.ar/normalizar/?direccion=JUAN JOSE PASO 648,caba&geocodificar=TRUE
# .
# .
# ...

# %%
def get_lat(url):
    try:
        response= requests.get(url)
        pattern='"y":."(.*?)"'
        if (re.findall(pattern, response.text)!=[]):
                lat.append(re.findall(pattern, response.text)[0])
                print('.')
        else:
            lat.append(np.nan)
            print( i )
       
    except:
        lat.append(np.nan)
        print('sin URL')

# %%
lat=[]
for i in SERIE_URL:
    get_lat(i)
# Out:
# .
# .
# .
# .
# .
# .
# .
# .
# .
# http://servicios.usig.buenosaires.gob.ar/normalizar/?direccion=STA MARIA DEL BUEN AYRE 871,caba&geocodificar=TRUE
# http://servicios.usig.buenosaires.gob.ar/normalizar/?direccion=GALVES 2275,caba&geocodificar=TRUE
# .
# http://servicios.usig.buenosaires.gob.ar/normalizar/?direccion=RL  FALCON 4981,caba&geocodificar=TRUE
# .
# .
# http://servicios.usig.buenosaires.gob.ar/normalizar/?direccion=CAAGUAZU 343,caba&geocodificar=TRUE
# .
# .
# .
# .
# .
# .
# .
# http://servicios.usig.buenosaires.gob.ar/normalizar/?direccion=OTAMANDI 464,caba&geocodificar=TRUE
# .
# http://servicios.usig.buenosaires.gob.ar/normalizar/?direccion=CNEL OLASCUAGA 5003,caba&geocodificar=TRUE
# .
# .
# .
# .
# .
# .
# http://servicios.usig.buenosaires.gob.ar/normalizar/?direccion=PIEDRA BUENA SEC C3,caba&geocodificar=TRUE
# .
# http://servicios.usig.buenosaires.gob.ar/normalizar/?direccion=JUAN JOSE PASO 648,caba&geocodificar=TRUE
# .
# .
# ...

# %%
def get_calle(url):
    try:
        response= requests.get(url)
        pattern='"nombre_calle":."(.*?)"'
        if (re.findall(pattern, response.text)!=[]):
                calle.append(re.findall(pattern, response.text)[0])
                print('.')
        else:
            calle.append(np.nan)
            print('sin calle')
    except:
        calle.append(np.nan)
        print('sin URL')

# %%
calle=[]
for i in SERIE_URL:
    get_calle(i)
    print
# Out:
# .
# .
# .
# .
# .
# .
# .
# .
# .
# sin calle
# sin calle
# .
# sin calle
# .
# .
# sin calle
# .
# .
# .
# .
# .
# .
# .
# sin calle
# .
# sin calle
# .
# .
# .
# .
# .
# .
# sin calle
# .
# sin calle
# .
# .
# sin calle
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# sin calle
# .
# .
# .
# sin calle
# .
# .
# sin calle
# .
# .
# .
# .
# .
# .
# .
# .
# sin calle
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# sin calle
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# sin calle
# .
# .
# sin calle
# .
# .
# sin calle
# sin calle
# sin calle
# .
# sin calle
# sin calle
# .
# .
# sin calle
# sin calle
# .
# sin calle
# sin calle
# .
# .
# .
# sin calle
# .
# .
# .
# .
# .
# .
# .
# .
# sin calle
# .
# .
# .
# ...

# %%
calle
# Out:
# ['MAGALLANES',
#  'MARMOL, JOSE',
#  'DEAN FUNES',
#  'MIRALLA',
#  'VIRGILIO',
#  'VIRGILIO',
#  'VIRGILIO',
#  'ORO\\u00d1O, NICASIO',
#  'EREZCANO',
#  nan,
#  nan,
#  'SANTA MARIA DEL BUEN AIRE',
#  nan,
#  'ACEVEDO, EDUARDO',
#  'JAURETCHE, ARTURO',
#  nan,
#  'YATAY',
#  'ALZAGA',
#  'LAS BASES',
#  'CAFAYATE',
#  'SOLER',
#  'CONSTITUCION',
#  'SOLDADO DE LA FRONTERA AV.',
#  nan,
#  'ACHA, MARIANO, GRAL.',
#  nan,
#  'HONDURAS AV.',
#  'SALVIGNY',
#  'POLA',
#  'ASAMBLEA AV.',
#  'LA PINTA',
#  'PERGAMINO',
#  nan,
#  'NU\\u00d1EZ',
#  nan,
#  'GAONA AV.',
#  'BALBASTRO',
#  nan,
#  'RAMIREZ, CEFERINO, COMODORO',
#  'SALVIGNY',
#  'SOLDADO DE LA FRONTERA AV.',
#  'ZEBALLOS, ESTANISLAO S.',
#  'FRANCO',
#  'LA GALERA',
#  'RONDEAU',
#  'TABARE',
#  'INDEPENDENCIA AV.',
#  'ALBARELLOS AV.',
#  'ALBARELLOS AV.',
#  'SAN PEDRITO',
#  'JUAREZ, BENITO',
#  'FONROUGE',
#  nan,
#  'NAVARRO',
#  'LADINES',
#  'RAFAELA',
#  nan,
#  'CALVO, CARLOS',
#  'MOZART',
#  nan,
# ...

# %%
def get_altura(url):
    try:
        response= requests.get(url)
        pattern='"altura":.(\d+)'
        if (re.findall(pattern, response.text)!=[]):
                altura.append(re.findall(pattern, response.text)[0])
                print('.')
        else:
            altura.append(np.nan)
            print('sin altura') 
    except:
        altura.append(np.nan)
        print('sin URL')

# %%
altura=[]
for i in SERIE_URL:
    get_altura(i)
    print
# Out:
# .
# .
# .
# .
# .
# .
# .
# .
# .
# sin altura
# sin altura
# .
# sin altura
# .
# .
# sin altura
# .
# .
# .
# .
# .
# .
# .
# sin altura
# .
# sin altura
# .
# .
# .
# .
# .
# .
# sin altura
# .
# sin altura
# .
# .
# sin altura
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# sin altura
# .
# .
# .
# sin altura
# .
# .
# sin altura
# .
# .
# .
# .
# .
# .
# .
# .
# sin altura
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# sin altura
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# sin altura
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# sin altura
# .
# .
# sin altura
# .
# .
# sin altura
# sin altura
# sin altura
# .
# sin altura
# sin altura
# .
# .
# sin altura
# sin altura
# .
# sin altura
# sin altura
# .
# .
# .
# sin altura
# .
# .
# .
# .
# .
# .
# .
# ...

# %%
altura=pd.Series(altura)
calle=pd.Series(calle)

# %%
data=pd.concat([data,calle,altura], axis=1)

# %%
data
# Out:
#      numero            fecha_vto             apellido_y_nombre  \
# 0     C0001  2019-01-31 00:00:00           OTERO ESTELA ALICIA
# 1     C0002                  NaN        BRUSATORI MARÍA SUSANA
# 2     C0003  2019-03-31 00:00:00       BOYADJIAN FABIAN ARIEL
# 3     C0004  2019-01-31 00:00:00         DAVERIO OSCAR GABRIEL
# 4     C0005  2018-11-30 00:00:00          DAPARO MARTÍN ADRIAN
# 5     C0006  2019-09-30 00:00:00       DAPARO SALVADOR MIGUEL
# 6     C0007  2019-09-30 00:00:00         BERNAY BEATRIZ JOSEFA
# 7     C0008  2019-03-31 00:00:00                  RATIS MIGUEL
# 8     C0009  2019-01-31 00:00:00        FERRER JORGE GUILLERMO
# 9     C0010  2019-01-31 00:00:00          SANTOS ANTONIO RUBEN
# 10    C0011                  NaN           DIAZ OSCAR ALBERTO
# 11    C0012  2019-01-31 00:00:00          CHAIN ARACELI RAQUEL
# 12    C0013  2019-01-31 00:00:00            FILARDO JORGE JOSE
# 13    C0014                  NaN         SANTIAGO LUIS ALBERTO
# ...

# %%
data.columns=[            'numero',          'fecha_vto',  'apellido_y_nombre',
         'numero_documento', 'titular_si', 'titular_de_licencia',    'domicilio_legal', 'dominio', 'papel_de_seguridad',
                     'CABA',          'piso_dpto', 'DOMICILIO_URL_CABA',
                          'calle',                    'altura']

# %%
datos_utiles_url=[]
for i in data['calle']:
    try:
        datos_utiles_url.append('http://ws.usig.buenosaires.gob.ar/datos_utiles/?callback=?&calle='+i+'&altura=')
    except:
        datos_utiles_url.append(np.nan)
        print('es un nan')
# Out:
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# es un nan
# ...

# %%
datos_utiles_url_=pd.Series(datos_utiles_url)+data['altura'].astype(str)

# %%
altura_url=data['altura'].values.astype(str)

# %%
def get_comuna(url):
    try:
        response= requests.get(url)
        pattern='"comuna":"(Comuna.\d+)"'
        if response.status_code == 200:
            comuna.append(re.findall(pattern, response.text)[0])
            print('.')

        return comuna
    except:
        print(url)
        comuna.append(np.nan)

# %%
comuna=[]
for i in datos_utiles_url_:
    get_comuna(i)
# Out:
# .
# .
# .
# .
# .
# .
# .
# http://ws.usig.buenosaires.gob.ar/datos_utiles/?callback=?&calle=ORO\u00d1O, NICASIO&altura=1268
# .
# nan
# nan
# .
# nan
# .
# .
# nan
# .
# .
# .
# .
# .
# .
# .
# nan
# .
# nan
# .
# .
# .
# .
# .
# .
# nan
# http://ws.usig.buenosaires.gob.ar/datos_utiles/?callback=?&calle=NU\u00d1EZ&altura=5929
# nan
# .
# .
# nan
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# nan
# .
# .
# .
# nan
# .
# .
# nan
# .
# .
# .
# .
# .
# .
# .
# .
# nan
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# http://ws.usig.buenosaires.gob.ar/datos_utiles/?callback=?&calle=BERGANTIN NANCY&altura=nan
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# nan
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# nan
# .
# .
# nan
# .
# .
# nan
# nan
# nan
# .
# nan
# nan
# ...

# %%
def get_barrio(url):
    try:
        response= requests.get(url)
        pattern='"barrio":"(.*?)"'
        if response.status_code == 200:
            barrio.append(re.findall(pattern, response.text)[0])
            print('.')


        return barrio
    except:
        print('XXXX')
        barrio.append(np.nan)

# %%
barrio=[]
for i in datos_utiles_url_:
    get_barrio(i)
# Out:
# .
# .
# .
# .
# .
# .
# .
# XXXX
# .
# XXXX
# XXXX
# .
# XXXX
# .
# .
# XXXX
# .
# .
# .
# .
# .
# .
# .
# XXXX
# .
# XXXX
# .
# .
# .
# .
# .
# .
# XXXX
# XXXX
# XXXX
# .
# .
# XXXX
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# XXXX
# .
# .
# .
# XXXX
# .
# .
# XXXX
# .
# .
# .
# .
# .
# .
# .
# .
# XXXX
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# XXXX
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# XXXX
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# XXXX
# .
# .
# XXXX
# .
# .
# XXXX
# XXXX
# XXXX
# .
# XXXX
# XXXX
# .
# .
# XXXX
# XXXX
# .
# XXXX
# XXXX
# .
# .
# .
# XXXX
# .
# .
# .
# .
# .
# XXXX
# .
# .
# XXXX
# .
# .
# .
# XXXX
# .
# .
# .
# .
# .
# .
# .
# XXXX
# XXXX
# .
# .
# XXXX
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# XXXX
# .
# XXXX
# .
# .
# ...

# %%
def get_cp(url):
    try:
        response= requests.get(url)
        pattern='"codigo_postal":"(.*?)"'
        if response.status_code == 200:
            cp.append(re.findall(pattern, response.text)[0])
            print('.')

        return cp
    except:
        print('XXXX')
        cp.append(np.nan)

# %%
cp=[]
for i in datos_utiles_url_:
    get_cp(i)
# Out:
# .
# .
# .
# .
# .
# .
# .
# XXXX
# .
# XXXX
# XXXX
# .
# XXXX
# .
# .
# XXXX
# .
# .
# .
# .
# .
# .
# .
# XXXX
# .
# XXXX
# .
# .
# .
# .
# .
# .
# XXXX
# XXXX
# XXXX
# .
# .
# XXXX
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# XXXX
# .
# .
# .
# XXXX
# .
# .
# XXXX
# .
# .
# .
# .
# .
# .
# .
# XXXX
# XXXX
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# XXXX
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# XXXX
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# XXXX
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# XXXX
# .
# .
# XXXX
# .
# .
# XXXX
# XXXX
# XXXX
# .
# XXXX
# XXXX
# .
# .
# XXXX
# XXXX
# .
# XXXX
# XXXX
# .
# .
# .
# XXXX
# .
# .
# .
# .
# .
# XXXX
# .
# .
# XXXX
# .
# .
# .
# XXXX
# .
# .
# .
# .
# .
# .
# .
# XXXX
# XXXX
# .
# .
# XXXX
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# XXXX
# .
# XXXX
# ...

# %%
def get_cpa(url):
    try:
        response= requests.get(url)
        pattern='"codigo_postal_argentino":"(.*?)"'
        if response.status_code == 200:
            cpa.append(re.findall(pattern, response.text)[0])
            print('.')

        return cpa
    except:
        print('XXXX')
        cpa.append(np.nan)

# %%
cpa=[]
for i in datos_utiles_url_:
    get_cpa(i)
# Out:
# .
# .
# .
# .
# .
# .
# .
# XXXX
# .
# XXXX
# XXXX
# .
# XXXX
# .
# .
# XXXX
# .
# .
# .
# .
# .
# .
# .
# XXXX
# .
# XXXX
# .
# .
# .
# .
# .
# .
# XXXX
# XXXX
# XXXX
# .
# .
# XXXX
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# XXXX
# .
# .
# .
# XXXX
# .
# .
# XXXX
# .
# .
# .
# .
# .
# .
# .
# XXXX
# XXXX
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# XXXX
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# XXXX
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# XXXX
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# XXXX
# .
# .
# XXXX
# .
# .
# XXXX
# XXXX
# XXXX
# .
# XXXX
# XXXX
# .
# .
# XXXX
# XXXX
# .
# XXXX
# XXXX
# .
# .
# .
# XXXX
# .
# .
# .
# .
# .
# XXXX
# .
# .
# XXXX
# .
# .
# .
# XXXX
# .
# .
# .
# .
# .
# .
# .
# XXXX
# XXXX
# .
# .
# XXXX
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# XXXX
# .
# XXXX
# ...

# %%
x=pd.Series(x)
lat=pd.Series(lat)
barrio=pd.Series(barrio)
comuna=pd.Series(comuna)
cp=pd.Series(cp)
cpa=pd.Series(cpa)

# %%
data2=pd.concat([data,x,lat,barrio,comuna,cp,cpa], axis=1)

# %%
data2=data2[['numero',           'fecha_vto',   'apellido_y_nombre',
          'numero_documento',          'titular_si', 'titular_de_licencia',
           'domicilio_legal', 'calle', 'altura', 'piso_dpto',            'dominio',  'papel_de_seguridad', 0,
                           1,                     2,                     3,
                           4,                     5]]

# %%
data2.columns=['numero',           'fecha_vto',   'apellido_y_nombre',
          'numero_documento',          'titular_si', 'titular_de_licencia',
           'domicilio_legal',               'calle',              'altura',
                 'piso_dpto',             'dominio',  'papel_de_seguridad',
                           'long',                     'lat',                     'barrio',
                           'comuna',                     'codigo_postal',                     'codigo_postal_argentina']

# %%
data2.fecha_vto[1780]='2018-10-31'
data2.fecha_vto[1005]='2017-05-17'

# %%
data2.fecha_vto=data2.fecha_vto.apply(lambda x: pd.to_datetime(x, yearfirst=True))

# %%
data2.to_csv('conductores-autorizados-de-servicios-escolares-20181008.csv', index=False)

# %%
data2['periodo']='2018 SEPTIEMBRE'

# %%
datah=pd.read_csv('registro-historico-acumulado-de-conductores-autorizados-de-servicios-escolares.csv')

# %%
data2.columns
# Out:
# Index(['numero', 'fecha_vto', 'apellido_y_nombre', 'numero_documento',
#        'titular_si', 'titular_de_licencia', 'domicilio_legal', 'calle',
#        'altura', 'piso_dpto', 'dominio', 'papel_de_seguridad', 'long', 'lat',
#        'barrio', 'comuna', 'codigo_postal', 'codigo_postal_argentina',
#        'periodo'],
#       dtype='object')

# %%
data2=data2[['periodo', 'numero', 'fecha_vto', 'apellido_y_nombre', 'numero_documento',
       'titular_si', 'titular_de_licencia', 'domicilio_legal', 'dominio', 'papel_de_seguridad', 'long', 'lat',
       'barrio', 'comuna', 'codigo_postal', 'codigo_postal_argentina']]

# %%
datah.FECHA_VTO[9675]='2018-10-31'
datah.FECHA_VTO[8900]='2017-05-17'
# Out:
# C:\Users\rama_\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\rama_\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
data2
# Out:
#               periodo numero  fecha_vto             apellido_y_nombre  \
# 0     2018 SEPTIEMBRE  C0001 2019-01-31           OTERO ESTELA ALICIA
# 1     2018 SEPTIEMBRE  C0002        NaT        BRUSATORI MARÍA SUSANA
# 2     2018 SEPTIEMBRE  C0003 2019-03-31       BOYADJIAN FABIAN ARIEL
# 3     2018 SEPTIEMBRE  C0004 2019-01-31         DAVERIO OSCAR GABRIEL
# 4     2018 SEPTIEMBRE  C0005 2018-11-30          DAPARO MARTÍN ADRIAN
# 5     2018 SEPTIEMBRE  C0006 2019-09-30       DAPARO SALVADOR MIGUEL
# 6     2018 SEPTIEMBRE  C0007 2019-09-30         BERNAY BEATRIZ JOSEFA
# 7     2018 SEPTIEMBRE  C0008 2019-03-31                  RATIS MIGUEL
# 8     2018 SEPTIEMBRE  C0009 2019-01-31        FERRER JORGE GUILLERMO
# 9     2018 SEPTIEMBRE  C0010 2019-01-31          SANTOS ANTONIO RUBEN
# 10    2018 SEPTIEMBRE  C0011        NaT           DIAZ OSCAR ALBERTO
# 11    2018 SEPTIEMBRE  C0012 2019-01-31          CHAIN ARACELI RAQUEL
# ...

# %%
data2.columns
# Out:
# Index(['periodo', 'numero', 'fecha_vto', 'apellido_y_nombre',
#        'numero_documento', 'titular_si', 'titular_de_licencia',
#        'domicilio_legal', 'dominio', 'papel_de_seguridad', 'long', 'lat',
#        'barrio', 'comuna', 'codigo_postal', 'codigo_postal_argentina'],
#       dtype='object')

# %%
datah=datah[['PERIODO', 'NUMERO', 'FECHA_VTO', 'APELLIDO_NOMBRE', 'DNI',
       'TITULAR _SI_NO', 'TITULAR_DE_LICENCIA', 'DOMICILIO_LEGAL', 'DOMINIO',
       'PAPEL_DE_SEGURIDAD','LONG', 'LAT', 'BARRIO', 'COMUNA', 'CODIGO_POSTAL',
       'CODIGO_POSTAL_ARGENTINO']]

# %%
datah.columns=['periodo', 'numero', 'fecha_vto', 'apellido_y_nombre',
       'numero_documento', 'titular_si', 'titular_de_licencia',
       'domicilio_legal', 'dominio', 'papel_de_seguridad', 'long', 'lat',
       'barrio', 'comuna', 'codigo_postal', 'codigo_postal_argentina']

# %%
datasubir=pd.concat([datah,data2], axis=0)

# %%
datasubir['long']=datasubir['long'].str.replace(',', '.')
datasubir['lat']=datasubir['lat'].str.replace(',', '.')

# %%
datasubir.to_csv('conductores-autorizados-de-servicios-escolares-historico-20181008.csv', index=False)

# %% [markdown]
# ## Radiotaxi empresas

# %%
data=pd.read_csv('agencias-de-radio-taxis.csv', sep='\t')

# %%
data
# Out:
#          long        lat  razon_social                         domicilio  \
# 0  -58.447096 -34.600090           ALO                        SERRANO 49
# 1  -58.418615 -34.608454    BUEN VIAJE               DIAZ VELEZ AV. 3699
# 2  -58.500001 -34.618299  BUENOS AIRES                     SANABRIA 1979
# 3  -58.417633 -34.630284      CAMINITO                    PAVON AV. 3795
# 4  -58.476757 -34.543474       CAPITAL                        ARIAS 2772
# 5  -58.432709 -34.626446    CIBER TAXI                      BEAUCHEF 791
# 6  -58.462477 -34.607984      CITY TAX  ALVAREZ, DONATO, TTE. GRAL. 1666
# 7  -58.451688 -34.581485       CLASSIC        LACROZE, FEDERICO AV. 3591
# 8  -58.496937 -34.552199       CONFORT                   VALDENEGRO 4699
# 9  -58.516419 -34.609324     DEL PLATA                      ALLENDE 3465
# 10 -58.423965 -34.614867       DIGITAL       YRIGOYEN, HIPOLITO AV. 4064
# 11 -58.399310 -34.618645        EIFFEL            INDEPENDENCIA AV. 2334
# ...

# %%
data['calle']=data.domicilio.str.split('(\s+[0-9]{1,})', expand=True)[0]

# %%
data['altura']=data.domicilio.str.split('(\s+[0-9]{1,})', expand=True)[1]

# %%
data.columns
# Out:
# Index(['long', 'lat', 'razon_social', 'domicilio', 'piso_dpto', 'barrio',
#        'comuna', 'codigo_postal', 'codigo_postal_argentino', 'telefono',
#        'cuit', 'calle', 'altura'],
#       dtype='object')

# %%
data=data[['long', 'lat', 'razon_social','telefono','cuit', 'calle', 'altura', 'piso_dpto', 'barrio',
       'comuna', 'codigo_postal', 'codigo_postal_argentino']]

# %%
data.to_csv('agencias-de-radio-taxis-20181005.csv', index=False)

# %%
historico=pd.read_csv('registro-historico-acumulado-de-radio-taxis.csv', sep=';')

# %%
data['periodo']='2018- SEPTIEMBRE'

# %%
historico
# Out:
#                X            Y       PERIODO  RAZON_SOCIAL  \
# 0    -58,4770288  -34,5832358    2016- MAYO      24 HORAS
# 1    -58,4470958    -34,60009    2016- MAYO           ALO
# 2    -58,4186149  -34,6084543    2016- MAYO    BUEN VIAJE
# 3    -58,5000011  -34,6182995    2016- MAYO  BUENOS AIRES
# 4    -58,5008893  -34,6524396    2016- MAYO      C.A.R.T.
# 5    -58,4176332  -34,6302842    2016- MAYO      CAMINITO
# 6    -58,4767568  -34,5434739    2016- MAYO       CAPITAL
# 7    -58,4327093  -34,6264458    2016- MAYO    CIBER TAXI
# 8    -58,4624767  -34,6079844    2016- MAYO      CITY TAX
# 9     -58,451688  -34,5814852    2016- MAYO       CLASSIC
# 10   -58,4969371  -34,5521992    2016- MAYO       CONFORT
# 11   -58,5164187  -34,6093237    2016- MAYO     DEL PLATA
# 12   -58,4239654  -34,6148669    2016- MAYO       DIGITAL
# 13   -58,3993103  -34,6186446    2016- MAYO        EIFFEL
# 14   -58,4249249  -34,6368242    2016- MAYO   EL TAXI SRL
# ...

# %%
historico['calle']=historico.DOMICILIO.str.split('(\s+[0-9]{1,})', expand=True)[0]

# %%
historico['altura']=historico.DOMICILIO.str.split('(\s+[0-9]{1,})', expand=True)[1]

# %%
data['periodo']='2018-SEPTIEMBRE'

# %%
data=data[['long', 'lat','periodo', 'razon_social', 'telefono', 'cuit', 'calle', 'altura',
       'piso_dpto', 'barrio', 'comuna', 'codigo_postal',
       'codigo_postal_argentino']]

# %%
data.columns
# Out:
# Index(['long', 'lat', 'periodo', 'razon_social', 'telefono', 'cuit', 'calle',
#        'altura', 'piso_dpto', 'barrio', 'comuna', 'codigo_postal',
#        'codigo_postal_argentino'],
#       dtype='object')

# %%
historico.columns
# Out:
# Index(['long', 'lat', 'periodo', 'razon_social', 'telefono', 'cuit', 'calle',
#        'altura', 'piso_dpto', 'barrio', 'comuna', 'codigo_postal',
#        'codigo_postal_argentino'],
#       dtype='object')

# %%
historico=historico[['X', 'Y', 'PERIODO', 'RAZON_SOCIAL', 'TELEFONO', 'CUIT', 'calle',
       'altura', 'PISO_DPTO', 'BARRIO',
       'COMUNA', 'CODIGO_POSTAL', 'CPA']]

# %%
historico.columns=['long', 'lat', 'periodo', 'razon_social', 'telefono', 'cuit', 'calle', 'altura', 'piso_dpto', 'barrio', 'comuna', 'codigo_postal', 'codigo_postal_argentino']

# %%
historico
# Out:
#             long          lat       periodo  razon_social   telefono  \
# 0    -58,4770288  -34,5832358    2016- MAYO      24 HORAS  4523-2222
# 1    -58,4470958    -34,60009    2016- MAYO           ALO  4855-5555
# 2    -58,4186149  -34,6084543    2016- MAYO    BUEN VIAJE  5252-9999
# 3    -58,5000011  -34,6182995    2016- MAYO  BUENOS AIRES  4566-7777
# 4    -58,5008893  -34,6524396    2016- MAYO      C.A.R.T.  4682-0000
# 5    -58,4176332  -34,6302842    2016- MAYO      CAMINITO  4925-2626
# 6    -58,4767568  -34,5434739    2016- MAYO       CAPITAL  4702-1111
# 7    -58,4327093  -34,6264458    2016- MAYO    CIBER TAXI  4921-6006
# 8    -58,4624767  -34,6079844    2016- MAYO      CITY TAX  4585-5544
# 9     -58,451688  -34,5814852    2016- MAYO       CLASSIC  4674-4444
# 10   -58,4969371  -34,5521992    2016- MAYO       CONFORT  4544-8686
# 11   -58,5164187  -34,6093237    2016- MAYO     DEL PLATA  4505-1111
# 12   -58,4239654  -34,6148669    2016- MAYO       DIGITAL  4637-3333
# ...

# %%
data
# Out:
#          long        lat          periodo  razon_social   telefono  \
# 0  -58.447096 -34.600090  2018-SEPTIEMBRE           ALO  4855-5555
# 1  -58.418615 -34.608454  2018-SEPTIEMBRE    BUEN VIAJE  5252-9999
# 2  -58.500001 -34.618299  2018-SEPTIEMBRE  BUENOS AIRES  4566-7777
# 3  -58.417633 -34.630284  2018-SEPTIEMBRE      CAMINITO  4925-2626
# 4  -58.476757 -34.543474  2018-SEPTIEMBRE       CAPITAL  4702-1111
# 5  -58.432709 -34.626446  2018-SEPTIEMBRE    CIBER TAXI  4921-6006
# 6  -58.462477 -34.607984  2018-SEPTIEMBRE      CITY TAX  4585-5544
# 7  -58.451688 -34.581485  2018-SEPTIEMBRE       CLASSIC  4674-4444
# 8  -58.496937 -34.552199  2018-SEPTIEMBRE       CONFORT  4544-8686
# 9  -58.516419 -34.609324  2018-SEPTIEMBRE     DEL PLATA  4505-1111
# 10 -58.423965 -34.614867  2018-SEPTIEMBRE       DIGITAL  4637-3333
# 11 -58.399310 -34.618645  2018-SEPTIEMBRE        EIFFEL  4308-4777
# 12 -58.422445 -34.624877  2018-SEPTIEMBRE       EL TAXI  4922-9999
# ...

# %%
histsubir=pd.concat([historico,data], axis=0)

# %%
histsubir.to_csv('historico-agencias-de-radio-taxi-20181005.csv', index=False)

# %% [markdown]
# ## Remiserías

# %%
data=pd.read_excel('AGENCIAS DE REMIS HABILITADAS_v2.xls')

# %%
data
# Out:
#      Matricula                 RazonSocial              NombreFantasia  \
# 0           28         T.DEL CARMEN S.R.L.         T.DEL CARMEN S.R.L.
# 1           32               AUTOREMY SRL.               AUTOREMY SRL.
# 2           69               TRAVEL S.R.L.                      TRAVEL
# 3           83                     RAMIREZ                     RAMIREZ
# 4          120                     TORRIFE                     TORRIFE
# 5          131                   "MONTANA"                   "MONTANA"
# 6          139               "COR MAR".SRL               "COR MAR".SRL
# 7          194               DEL BUEN AYRE               DEL BUEN AYRE
# 8          236                   "OLIMPIA"                   "OLIMPIA"
# 9          243            AGENCIA RENT-CAR            AGENCIA RENT-CAR
# 10         273                     RENTUR                       RENTUR
# 11         358                   HORIZONTE                   HORIZONTE
# ...

# %%
data['periodo']='2018 SEPTIEMBRE'

# %%
data['Matricula']=data['Matricula'].fillna(0).astype(int)

# %%
data['Calle']=data['Calle'].str.replace('C.MA.RAMIREZ', 'CARLOS MARÍA RAMIREZ')
data['Calle']=data['Calle'].str.replace('A. S. JUAN DE LASALLE', 'AV. SAN JUAN BAUTISTA DE LA SALLE')
data['Calle']=data['Calle'].str.replace('AV.IBARROLA', 'IBARROLA')
data['Calle']=data['Calle'].str.replace('GRAL.E.GARZON UF/3', 'GRAL. EUGENIO GARZON')
data['Calle']=data['Calle'].str.replace('PTE.LUIS SAENZ PEÑA', 'PRES. LUIS SAENZ PEÑA')
data['Calle']=data['Calle'].str.replace('APOLINARO FIGUEROA', 'APOLINARIO FIGUEROA')
data['Calle']=data['Calle'].str.replace('COMBATE DE MALVINAS', 'COMBATIENTES DE MALVINAS')

# %%
data['CALLE_ALTURA']=data['Calle']+ ' ' + data['Numero'].fillna('').astype(str)

# %%
direccion_url=[]
for i in data['CALLE_ALTURA']:
    try:
        direccion_url.append('http://servicios.usig.buenosaires.gob.ar/normalizar/?direccion='+i+',caba&geocodificar=TRUE')
    except:
        direccion_url.append(np.nan)

# %%
len(direccion_url)
# Out:
# 115

# %%
def get_x(dir):
    try:
        response= requests.get(dir)
        pattern='"x":."(.\d+.\d+)"'
        
        if (re.findall(pattern, response.text)!=[]):
            x.append(re.findall(pattern, response.text)[0])
            print('.')
        else:
            x.append(np.nan)
            print( i )
    except:
        x.append(np.nan)
        print('no existe URL'+ i)

# %%
x=[]
for i in direccion_url:
    get_x(i)
# Out:
# .
# .
# .
# http://servicios.usig.buenosaires.gob.ar/normalizar/?direccion=CARLOS MARÍA RAMIREZ 2247,caba&geocodificar=TRUE
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .

# %%
x
# Out:
# ['-58.390093',
#  '-58.393062',
#  '-58.499442',
#  nan,
#  '-58.459999',
#  '-58.460662',
#  '-58.409403',
#  '-58.377693',
#  '-58.471421',
#  '-58.453429',
#  '-58.461263',
#  '-58.466067',
#  '-58.501237',
#  '-58.514298',
#  '-58.464734',
#  '-58.379303',
#  '-58.386323',
#  '-58.517391',
#  '-58.423267',
#  '-58.511113',
#  '-58.475184',
#  '-58.392322',
#  '-58.476961',
#  '-58.528829',
#  '-58.380032',
#  '-58.466530',
#  '-58.475860',
#  '-58.501502',
#  '-58.477162',
#  '-58.414343',
#  '-58.363666',
#  '-58.397008',
#  '-58.416511',
#  '-58.407310',
#  '-58.404864',
#  '-58.443892',
#  '-58.524044',
#  '-58.383538',
#  '-58.386100',
#  '-58.424703',
#  '-58.444090',
#  '-58.374366',
#  '-58.461039',
#  '-58.432818',
#  '-58.387924',
#  '-58.450591',
#  '-58.373764',
#  '-58.371376',
#  '-58.455376',
#  '-58.432870',
#  '-58.503835',
#  '-58.528304',
#  '-58.421378',
#  '-58.388178',
#  '-58.473384',
#  '-58.486447',
#  '-58.483640',
#  '-58.435744',
#  '-58.469390',
# ...

# %%
def get_lat(url):
    try:
        response= requests.get(url)
        pattern='"y":."(.*?)"'
        if (re.findall(pattern, response.text)!=[]):
                lat.append(re.findall(pattern, response.text)[0])
                print('.')
        else:
            lat.append(np.nan)
            print( i )
       
    except:
        lat.append(np.nan)
        print('sin URL')

# %%
lat=[]
for i in direccion_url:
    get_lat(i)
# Out:
# .
# .
# .
# http://servicios.usig.buenosaires.gob.ar/normalizar/?direccion=CARLOS MARÍA RAMIREZ 2247,caba&geocodificar=TRUE
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .

# %%
datos_utiles_url=[]
for i in data['Calle']:
    try:
        datos_utiles_url.append('http://ws.usig.buenosaires.gob.ar/datos_utiles/?callback=?&calle='+i+'&altura=')
    except:
        datos_utiles_url.append(np.nan)
        print('es un nan')

# %%
datos_utiles_url_=pd.Series(datos_utiles_url)+data['Numero'].astype(str)

# %%
datos_utiles_url_.values
# Out:
# array(['http://ws.usig.buenosaires.gob.ar/datos_utiles/?callback=?&calle=DEL CARMEN&altura=732',
#        'http://ws.usig.buenosaires.gob.ar/datos_utiles/?callback=?&calle=AV. CALLAO&altura=1235',
#        'http://ws.usig.buenosaires.gob.ar/datos_utiles/?callback=?&calle=JUAN B. ALBERDI&altura=5476',
#        'http://ws.usig.buenosaires.gob.ar/datos_utiles/?callback=?&calle=CARLOS MARÍA RAMIREZ&altura=2247',
#        'http://ws.usig.buenosaires.gob.ar/datos_utiles/?callback=?&calle=AV. FERNANDEZ DE LA CRUZ&altura=4602',
#        'http://ws.usig.buenosaires.gob.ar/datos_utiles/?callback=?&calle=MONROE&altura=2469',
#        'http://ws.usig.buenosaires.gob.ar/datos_utiles/?callback=?&calle=SARMIENTO&altura=3057',
#        'http://ws.usig.buenosaires.gob.ar/datos_utiles/?callback=?&calle=PIEDRAS&altura=150',
#        'http://ws.usig.buenosaires.gob.ar/datos_utiles/?callback=?&calle=MANUELA PEDRAZA&altura=2994',
# ...

# %%
def get_comuna(url):
    try:
        response= requests.get(url)
        pattern='"comuna":"(Comuna.\d+)"'
        if response.status_code == 200:
            comuna.append(re.findall(pattern, response.text)[0])
            print('.')

        return comuna
    except:
        print(url)
        comuna.append(np.nan)

# %%
comuna=[]
for i in datos_utiles_url_:
    get_comuna(i)
# Out:
# .
# .
# .
# http://ws.usig.buenosaires.gob.ar/datos_utiles/?callback=?&calle=CARLOS MARÍA RAMIREZ&altura=2247
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .

# %%
def get_barrio(url):
    try:
        response= requests.get(url)
        pattern='"barrio":"(.*?)"'
        if response.status_code == 200:
            barrio.append(re.findall(pattern, response.text)[0])
            print('.')


        return barrio
    except:
        print(url)
        barrio.append(np.nan)

# %%
barrio=[]
for i in datos_utiles_url_:
    get_barrio(i)
# Out:
# .
# .
# .
# http://ws.usig.buenosaires.gob.ar/datos_utiles/?callback=?&calle=CARLOS MARÍA RAMIREZ&altura=2247
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .

# %%
def get_cp(url):
    try:
        response= requests.get(url)
        pattern='"codigo_postal":"(.*?)"'
        if response.status_code == 200:
            cp.append(re.findall(pattern, response.text)[0])
            print('.')

        return cp
    except:
        print(url)
        cp.append(np.nan)

# %%
cp=[]
for i in datos_utiles_url_:
    get_cp(i)
# Out:
# .
# .
# .
# http://ws.usig.buenosaires.gob.ar/datos_utiles/?callback=?&calle=CARLOS MARÍA RAMIREZ&altura=2247
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .

# %%
def get_cpa(url):
    try:
        response= requests.get(url)
        pattern='"codigo_postal_argentino":"(.*?)"'
        if response.status_code == 200:
            cpa.append(re.findall(pattern, response.text)[0])
            print('.')

        return cpa
    except:
        print(url)
        cpa.append(np.nan)

# %%
cpa=[]
for i in datos_utiles_url_:
    get_cpa(i)
# Out:
# .
# .
# .
# http://ws.usig.buenosaires.gob.ar/datos_utiles/?callback=?&calle=CARLOS MARÍA RAMIREZ&altura=2247
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# http://ws.usig.buenosaires.gob.ar/datos_utiles/?callback=?&calle=ARZOBISPO ESPINOSA&altura=376
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .

# %%
longitud= pd.Series(x)
latitud= pd.Series(lat)
barrio= pd.Series(barrio)
comuna= pd.Series(comuna)
cp= pd.Series(cp)
cpa= pd.Series(cpa)

# %%
data=pd.concat([data,longitud,latitud,barrio, comuna, cp,cpa], axis=1)

# %%
data.columns=['matricula',                     'razon_social',
                        'nombre_fantasia',                        'cuit_cuil',
                                 'calle',                          'altura',
                              'telefono', 'fecha_vencimiento',
                              'cantidad',                            'piso',
                               'periodo',                    'direccion',
                                       'long',                                 'lat',
                                       'barrio',                                 'comuna',
                                       'codigo_postal',                                 'codigo_postal_argentino']

# %%
data=data[['periodo', 'matricula', 'razon_social', 'nombre_fantasia', 'cuit_cuil', 'direccion', 'calle', 'altura',
          'piso', 'telefono',  'barrio',                                 'comuna',
                                       'codigo_postal',                                 'codigo_postal_argentino']]

# %%
data['barrio']=data['barrio'].str.replace('Nu\u00f1ez', 'Nuñez')

# %%
data.to_csv('remiserias-20181005.csv', index=False)

# %% [markdown]
# ## Transporte de escolares

# %%
data=pd.read_excel('VEHICULOS ESCOLARES HABILITADOS_v2.xls')

# %%
data.columns=['numero_habilitacion', 'titular', 'tipo_documento', 'numero_documento', 'dominio', 'marca',
       'modelo', 'vencimiento_habilitacion']

# %%
data['vencimiento_habilitacion']=data['vencimiento_habilitacion'].dt.date

# %%
data.to_csv('transporte-de-escolares-20181005.csv', index=False)

# %%
data['periodo']='2018 SEPTIEMBRE'

# %%
data=data[['periodo', 'numero_habilitacion', 'titular', 'numero_documento', 'tipo_documento','dominio','modelo', 'vencimiento_habilitacion']]

# %%
datah=pd.read_csv('registro-historico-acumulado-de-transportes-de-escolares-autorizados.csv')

# %%
datah.columns=['periodo', 'numero_habilitacion', 'titular', 'numero_documento',
       'tipo_documento', 'dominio', 'modelo', 'vencimiento_habilitacion']

# %%
data
# Out:
#               periodo  numero_habilitacion                          titular  \
# 0     2018 SEPTIEMBRE                 1243       DRISDALE, DANIEL ALEJANDRO
# 1     2018 SEPTIEMBRE                 9209      CARRANANTE, RICARDO ALFREDO
# 2     2018 SEPTIEMBRE                14656          SERRANO, MONICA CECILIA
# 3     2018 SEPTIEMBRE                21673            ARRIETA, JOSE RODOLFO
# 4     2018 SEPTIEMBRE                25837          DI, CROCE DARIO MARCELO
# 5     2018 SEPTIEMBRE                25921              CIRUZZI, MARIA JOSE
# 6     2018 SEPTIEMBRE                27783      GALLARDO, CHRISTIAN RICARDO
# 7     2018 SEPTIEMBRE                28447       COLOMBERA, ALBERTO EDGARDO
# 8     2018 SEPTIEMBRE                30391  MANSILLA, CARLOS EDUARDO FABIAN
# 9     2018 SEPTIEMBRE                32226          ANNARATONE, OSCAR MARIO
# 10    2018 SEPTIEMBRE                32244            CUNEO, VIVIANA ALICIA
# ...

# %%
datahistorica=pd.concat([datah,data], axis=0)

# %%
datahistorica.to_csv('historico-transportes-de-escolares-autorizados.csv', index=False)

# %%
#falta: VENCIMIENTO_VTV, NUMERO_ASIENTOS
