# %%
import pandas as pd

# %%
import numpy as np
import requests
import re

# %%
data=pd.read_excel('Julio- Agosto - Septiembre 2018.xls', encoding='Latin1')

# %%
data.Calle
# Out:
# 0        FIGUEROA ALCORTA, PRES. AV.
# 1                         SANTO TOME
# 2                 CANTILO, JOSE LUIS
# 3              IRIGOYEN, BERNARDO DE
# 4                     PUEYRREDON AV.
# 5            FRAGATA PRES. SARMIENTO
# 6                              PINTO
# 7                             CONESA
# 8                            SERRANO
# 9                           CASTILLO
# 10                        SANTO TOME
# 11                     CALVO, CARLOS
# 12                           DEFENSA
# 13                   AGOTE, LUIS DR.
# 14                       SANTA ELENA
# 15                      SANTA FE AV.
# 16                        CALIFORNIA
# 17                          PARAGUAY
# 18                         NICARAGUA
# 19                          HONDURAS
# 20               SANTIAGO DEL ESTERO
# 21                           LLERENA
# 22       FIGUEROA ALCORTA, PRES. AV.
# 23                 WILLIAMS, ALBERTO
# 24               RIVAROLA, PANTALEON
# ...

# %%
data.Calle[data.Calle=='BUTTY, ENRIQUE, ING.']= 'BUTTY'
# Out:
# C:\Users\rama_\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
data['CALLE_ALTURA']=data['Calle']+ ' '+data['Altura'].astype(str)

# %%
direccion_url=[]
for i in data['CALLE_ALTURA']:
    try:
        direccion_url.append('http://servicios.usig.buenosaires.gob.ar/normalizar/?direccion='+i+',caba&geocodificar=TRUE&maxOptions=1')
    except:
        direccion_url.append(np.nan)

# %%
direccion_url
# Out:
# ['http://servicios.usig.buenosaires.gob.ar/normalizar/?direccion=FIGUEROA ALCORTA, PRES. AV. 2101,caba&geocodificar=TRUE&maxOptions=1',
#  'http://servicios.usig.buenosaires.gob.ar/normalizar/?direccion=SANTO TOME 4752,caba&geocodificar=TRUE&maxOptions=1',
#  'http://servicios.usig.buenosaires.gob.ar/normalizar/?direccion=CANTILO, JOSE LUIS 4156,caba&geocodificar=TRUE&maxOptions=1',
#  'http://servicios.usig.buenosaires.gob.ar/normalizar/?direccion=IRIGOYEN, BERNARDO DE 1650,caba&geocodificar=TRUE&maxOptions=1',
#  'http://servicios.usig.buenosaires.gob.ar/normalizar/?direccion=PUEYRREDON AV. 2601,caba&geocodificar=TRUE&maxOptions=1',
#  'http://servicios.usig.buenosaires.gob.ar/normalizar/?direccion=FRAGATA PRES. SARMIENTO 1023,caba&geocodificar=TRUE&maxOptions=1',
#  'http://servicios.usig.buenosaires.gob.ar/normalizar/?direccion=PINTO 3910,caba&geocodificar=TRUE&maxOptions=1',
# ...

# %%
def get_x(dir):
    try:
        response= requests.get(dir)
        pattern='"x":."(.\d+.\d+)"'

        if (re.findall(pattern, response.text)!=[]):
            x.append(re.findall(pattern, response.text))
            print('.')
        else:
            x.append(np.nan)
            print( i )
    except:
        x.append(np.nan)
        print('sin URL')
x=[]
for i in direccion_url:
    get_x(i)   

lon_normalizada=[]
for i in x:
    try:
        lon_normalizada.append((x[x.index(i)][0]))
    except: 
        lon_normalizada.append(np.nan)
data['X']=lon_normalizada
# Out:
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ...

# %%
def get_lat(url):
    try:
        response= requests.get(url)
        pattern='"y":."(.*?)"'
        if (re.findall(pattern, response.text)!=[]):
                lat.append(re.findall(pattern, response.text))
                print('.')
        else:
            lat.append(np.nan)
            print( i )
       
    except:
        lat.append(np.nan)
        print('sin URL')
lat=[]
for i in direccion_url:
    get_lat(i)
    print
    
lat_normalizada=[]
for i in lat:
    try:
        lat_normalizada.append((lat[lat.index(i)][0]))
    except: 
        lat_normalizada.append(np.nan)
        
data['y']=lat_normalizada
# Out:
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ...

# %%
data
# Out:
#                           Titulo                             Razon_social  \
# 0                TOPPER TRAINING                            Drimburo S.A.
# 1                  Otros Pecados                 Pol-ka Producciones S.A.
# 2                  Otros Pecados                 Pol-ka Producciones S.A.
# 3                  Otros Pecados                 Pol-ka Producciones S.A.
# 4                      coca-cola                     Kohler Studio S.R.L.
# 5      UN GALLO PARA ESCULAPIO 2            Underground Producciones S.A.
# 6               PUNTO DE QUIEBRE  Universidad nacional de Tres de Febrero
# 7               PUNTO DE QUIEBRE  Universidad nacional de Tres de Febrero
# 8                        Remeros                          Rebolución S.A.
# 9                        Remeros                          Rebolución S.A.
# 10                 Otros Pecados                 Pol-ka Producciones S.A.
# 11                 Morir de Amor             L C Acción Producciones S.A.
# ...

# %%
def get_calle(url):
    try:
        response= requests.get(url)
        pattern='"nombre_calle":."(.*?)"'
        if (re.findall(pattern, response.text)!=[]):
                calle.append(re.findall(pattern, response.text))
                print('.')
        else:
            calle.append(np.nan)
            print('sin calle')
    except:
        calle.append(np.nan)
        print('sin URL')
        
calle=[]
for i in direccion_url:
    get_calle(i)
    print
    
calle_normalizada=[]
for i in calle:
    try:
        calle_normalizada.append((calle[calle.index(i)][0]))
    except: 
        calle_normalizada.append(np.nan)
# Out:
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ...

# %%
def get_altura(url):
    try:
        response= requests.get(url)
        pattern='"altura":.(\d+)'
        if (re.findall(pattern, response.text)!=[]):
                altura.append(re.findall(pattern, response.text))
                print('.')
        else:
            altura.append(np.nan)
            print('sin altura') 
    except:
        altura.append(np.nan)
        print('sin URL')
        
altura=[]
for i in direccion_url:
    get_altura(i)
    print
    
altura_normalizada=[]
for i in altura:
    try:
        altura_normalizada.append((altura[altura.index(i)][0]))
    except: 
        altura_normalizada.append(np.nan)
# Out:
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ...

# %%
# data.DIRECCION=data.DIRECCION.str.replace('\\', '')
# data.DIRECCION=data.DIRECCION.str.replace('u00d1', 'Ñ')

# %%
calle_normalizada=pd.Series(calle_normalizada).str.replace('\\', '')
calle_normalizada=pd.Series(calle_normalizada).str.replace('u00d1', 'Ñ')

# %%
calle_normalizada=pd.Series(calle_normalizada).str.replace('u00b0', '')

# %%
data['DIRECCION']=pd.Series(calle_normalizada)+' '+ pd.Series(altura_normalizada)

# %%
direccion=[]
for i in data.DIRECCION:
    try:
        direccion.append(i.astype(str))
    except:
        direccion.append(i)

# %% [markdown]
#     # CONTINUAR CORRIGIENDO LA SERIE DIRECCION. POR EJEMPLO LAS ENIES, PARA LUEGO ES

# %%
datos_utiles_url=[]
for i in calle_normalizada:
    try:
        datos_utiles_url.append('http://ws.usig.buenosaires.gob.ar/datos_utiles/?callback=?&calle='+i+'&altura=')
    except:
        datos_utiles_url.append(np.nan)
        print('es un nan')
datos_utiles_url=(pd.Series(datos_utiles_url)+pd.Series(altura_normalizada))

# %%
datos_utiles_url.values
# Out:
# array(['http://ws.usig.buenosaires.gob.ar/datos_utiles/?callback=?&calle=FIGUEROA ALCORTA, PRES. AV.&altura=2101',
#        'http://ws.usig.buenosaires.gob.ar/datos_utiles/?callback=?&calle=SANTO TOME&altura=4752',
#        'http://ws.usig.buenosaires.gob.ar/datos_utiles/?callback=?&calle=CANTILO, JOSE LUIS&altura=4156',
#        'http://ws.usig.buenosaires.gob.ar/datos_utiles/?callback=?&calle=IRIGOYEN, BERNARDO DE&altura=1650',
#        'http://ws.usig.buenosaires.gob.ar/datos_utiles/?callback=?&calle=PUEYRREDON AV.&altura=2601',
#        'http://ws.usig.buenosaires.gob.ar/datos_utiles/?callback=?&calle=FRAGATA PRES. SARMIENTO&altura=1023',
#        'http://ws.usig.buenosaires.gob.ar/datos_utiles/?callback=?&calle=PINTO&altura=3910',
#        'http://ws.usig.buenosaires.gob.ar/datos_utiles/?callback=?&calle=CONESA&altura=4001',
#        'http://ws.usig.buenosaires.gob.ar/datos_utiles/?callback=?&calle=SERRANO&altura=1151',
# ...

# %%
def get_comuna(url):
    try:
        response= requests.get(url)
        pattern='"comuna":"(Comuna.\d+)"'
        if response.status_code == 200:
            comuna.append(re.findall(pattern, response.text)[0])
            print('.')

        return comuna
    except:
        print(url)
        comuna.append(np.nan)
        
comuna=[]
for i in datos_utiles_url:
    get_comuna(i)
    
data['COMUNA']=comuna
# Out:
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ...

# %%
data
# Out:
#                           Titulo                             Razon_social  \
# 0                TOPPER TRAINING                            Drimburo S.A.
# 1                  Otros Pecados                 Pol-ka Producciones S.A.
# 2                  Otros Pecados                 Pol-ka Producciones S.A.
# 3                  Otros Pecados                 Pol-ka Producciones S.A.
# 4                      coca-cola                     Kohler Studio S.R.L.
# 5      UN GALLO PARA ESCULAPIO 2            Underground Producciones S.A.
# 6               PUNTO DE QUIEBRE  Universidad nacional de Tres de Febrero
# 7               PUNTO DE QUIEBRE  Universidad nacional de Tres de Febrero
# 8                        Remeros                          Rebolución S.A.
# 9                        Remeros                          Rebolución S.A.
# 10                 Otros Pecados                 Pol-ka Producciones S.A.
# 11                 Morir de Amor             L C Acción Producciones S.A.
# ...

# %%
def get_barrio(url):
    try:
        response= requests.get(url)
        pattern='"barrio":"(.*?)"'
        if response.status_code == 200:
            barrio.append(re.findall(pattern, response.text)[0])
            print('.')


        return barrio
    except:
        print('XXXX')
        barrio.append(np.nan)
        
barrio=[]
for i in datos_utiles_url:
    get_barrio(i)
    
data['BARRIO']=barrio
# Out:
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ...

# %%
def get_cp(url):
    try:
        response= requests.get(url)
        pattern='"codigo_postal":"(.*?)"'
        if response.status_code == 200:
            cp.append(re.findall(pattern, response.text)[0])
            print('.')

        return cp
    except:
        print('XXXX')
        cp.append(np.nan)
        
cp=[]
for i in datos_utiles_url:
    get_cp(i)
    
data['CODIGO_POSTAL']=cp
# Out:
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# XXXX
# .
# .
# .
# .
# .
# .
# .
# .
# XXXX
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# XXXX
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ...

# %%
def get_cpa(url):
    try:
        response= requests.get(url)
        pattern='"codigo_postal_argentino":"(.*?)"'
        if response.status_code == 200:
            cpa.append(re.findall(pattern, response.text)[0])
            print('.')

        return cpa
    except:
        print('XXXX')
        cpa.append(np.nan)
        
cpa=[]
for i in datos_utiles_url:
    get_cpa(i)
    
data['CODIGO_POSTAL_ARGENTINO']=cpa
# Out:
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# XXXX
# .
# .
# .
# .
# .
# .
# .
# .
# XXXX
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# XXXX
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ...

# %%
data['TRIMESTRE']='3 TRIMESTRE 2018'

# %%
data
# Out:
#            long         lat         trimestre                       titulo  \
# 0    -58.390910  -34.583916  3 TRIMESTRE 2018              TOPPER TRAINING
# 1    -58.507893  -34.616790  3 TRIMESTRE 2018                Otros Pecados
# 2    -58.511143  -34.603134  3 TRIMESTRE 2018                Otros Pecados
# 3    -58.378148  -34.628001  3 TRIMESTRE 2018                Otros Pecados
# 4    -58.391707  -34.584747  3 TRIMESTRE 2018                    coca-cola
# 5    -58.454323  -34.612460  3 TRIMESTRE 2018    UN GALLO PARA ESCULAPIO 2
# 6    -58.477712  -34.549447  3 TRIMESTRE 2018             PUNTO DE QUIEBRE
# 7    -58.475699  -34.548684  3 TRIMESTRE 2018             PUNTO DE QUIEBRE
# 8    -58.435007  -34.591890  3 TRIMESTRE 2018                      Remeros
# 9    -58.442823  -34.587151  3 TRIMESTRE 2018                      Remeros
# 10   -58.507893  -34.616790  3 TRIMESTRE 2018                Otros Pecados
# ...

# %%
data.columns=['titulo', 'razon_social', 'tipo_produccion', 'fecha', 'calle', 'altura',
       'direccion_normalizada', 'long', 'lat', 'direccion', 'comuna',
       'barrio', 'codigo_postal', 'codigo_postal_argentino', 'trimestre']

# %%
data=data[['long', 'lat', 'trimestre','titulo', 'razon_social', 'tipo_produccion', 'fecha', 'direccion', 'calle', 'altura',
          'barrio', 'comuna', 'codigo_postal', 'codigo_postal_argentino']]

# %%
data.to_csv('permisos-filmacion-3trim-20181009.csv', index=False)
