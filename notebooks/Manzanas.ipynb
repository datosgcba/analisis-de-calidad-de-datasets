# %%
# !python -m pip install --upgrade setuptools
# Out:
# ...
#   Found existing installation: setuptools 39.1.0
#     Uninstalling setuptools-39.1.0:
#       Successfully uninstalled setuptools-39.1.0
# ...

# %%
# !python -m pip install --upgrade pip
# Out:
# ...
#   Found existing installation: pip 18.0
#     Uninstalling pip-18.0:
#       Successfully uninstalled pip-18.0
# ...

# %%
# !pip install shapely
# Out:
# ...
#   Using cached https://files.pythonhosted.org/packages/a2/fb/7a7af9ef7a35d16fa23b127abee272cfc483ca89029b73e92e93cdf36e6b/Shapely-1.6.4.post2.tar.gz
#     Complete output from command python setup.py egg_info:
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "C:\Users\rama_\AppData\Local\Temp\pip-install-j8cws9f4\shapely\setup.py", line 80, in <module>
#         from shapely._buildcfg import geos_version_string, geos_version, \
#       File "C:\Users\rama_\AppData\Local\Temp\pip-install-j8cws9f4\shapely\shapely\_buildcfg.py", line 200, in <module>
#         lgeos = CDLL("geos_c.dll")
#       File "c:\users\rama_\anaconda3\lib\ctypes\__init__.py", line 348, in __init__
#         self._handle = _dlopen(self._name, mode)
#     OSError: [WinError 126] The specified module could not be found
#
#     ----------------------------------------
# ...

# %%
import pandas as pd
import numpy as np
import re
import requests
from shapely.geometry import Polygon

# %%
data=pd.read_csv('mo_manzanasmap.csv')

# %%
len(data)
# Out:
# 12404

# %%
data=data[['geom', 'seccion', 'manzana', 'sm']]

# %%
data.columns=['WKT', 'seccion', 'manzana', 'sm']

# %%
data
# Out:
#                                                      WKT  seccion manzana  \
# 0      MULTIPOLYGON (((-58.52659887951971 -34.6128424...     89.0    029C
# 1      MULTIPOLYGON (((-58.360771123058186 -34.612609...     98.0    001T
# 2      MULTIPOLYGON (((-58.430594089198564 -34.612850...     45.0     143
# 3      MULTIPOLYGON (((-58.4425685476403 -34.61279197...     45.0     046
# 4      MULTIPOLYGON (((-58.52470708086542 -34.6127112...     89.0    033A
# 5      MULTIPOLYGON (((-58.381149954543055 -34.612434...     12.0     064
# 6      MULTIPOLYGON (((-58.38266117682387 -34.6125182...     12.0     054
# 7      MULTIPOLYGON (((-58.39828192471028 -34.6124879...     20.0     040
# 8      MULTIPOLYGON (((-58.4126825051546 -34.61316931...     28.0     032
# 9      MULTIPOLYGON (((-58.41607931241712 -34.6127247...     28.0     016
# 10     MULTIPOLYGON (((-58.448975955703794 -34.612739...     57.0     113
# 11     MULTIPOLYGON (((-58.380257316832655 -34.612375...     12.0     065
# ...

# %%
data.to_csv('manzanas-20181005.csv', index=False)

# %%
#https://stackoverflow.com/questions/40427022/polygon-perimeter
#https://gis.stackexchange.com/questions/127607/area-in-km-from-polygon-of-coordinates
#https://docs.qgis.org/2.18/en/docs/pyqgis_developer_cookbook/geometry.html
#https://mappinggis.com/2014/02/primeros-pasos-con-pyqgis/
