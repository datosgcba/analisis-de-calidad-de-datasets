# %%
import pandas as pd
import numpy as np

# %%
portal=pd.read_csv('sueldo-funcionarios-1-7.csv')

# %%
nuevo=pd.read_excel('funcionarios_0818.xlsx')

# %%
nuevo
# Out:
#          ID           CUIL  MES  ANIO                   APELLIDO_Y_NOMBRE  \
# 0   1116894  20-17692128-6    8  2018  RODRIGUEZ LARRETA, HORACIO ANTONIO
# 1   1454901  20-17735449-0    8  2018               SANTILLI, DIEGO CESAR
# 2    434331  20-21981279-6    8  2018          SCRENCI SILVA, BRUNO GUIDO
# 3   1053516  27-13221055-7    8  2018                BOU PEREZ, ANA MARIA
# 4   1117070  20-25641207-2    8  2018              AVOGADRO, ENRIQUE LUIS
# 5   1117085  20-24941711-5    8  2018                        MURA, MARTIN
# 6   1117136  20-17110752-1    8  2018       MACCHIAVELLI, EDUARDO ALBERTO
# 7   1117165  27-24483014-0    8  2018                ACU?A, MARIA SOLEDAD
# 8   1117272  27-13092400-5    8  2018               FREDA, MONICA BEATRIZ
# 9   1123130  27-24030362-6    8  2018              TAGLIAFERRI, GUADALUPE
# 10  1491677  20-14699669-9    8  2018                      MOCCIA, FRANCO
# 11  1547292  20-13872301-2    8  2018             ASTARLOA, GABRIEL MARIA
# ...

# %%
nuevo.APELLIDO_Y_NOMBRE=nuevo.APELLIDO_Y_NOMBRE.str.replace('?', 'Ñ')

# %%
portal.columns=['AÑO', 'MES', 'APELLIDO', 'NOMBRE', 'CARGO', 'TOTAL_ASIGNACIONES',
       'SALARIO_FAMILIAR', 'DESCUENTOS', 'LIQUIDO']

# %%
nuevo=nuevo[['MES', 'ANIO', 'APELLIDO_Y_NOMBRE', 'CARGO',
       'TOTAL_DE_ASIGNACIONES', 'SALARIO_FAMILIAR', 'TOTAL_DE_DESCUENTOS',
       'LIQUIDO']]

# %%
nuevo.columns=['MES', 'AÑO', 'APELLIDO_Y_NOMBRE', 'CARGO', 'TOTAL_ASIGNACIONES',
       'SALARIO_FAMILIAR', 'DESCUENTOS', 'LIQUIDO']

# %%
nomyap=nuevo.APELLIDO_Y_NOMBRE.str.split(',', expand=True)

# %%
nuevo=pd.concat([nuevo,nomyap], axis=1)

# %%
nuevo.columns=['MES', 'AÑO', 'APELLIDO_Y_NOMBRE', 'CARGO', 'TOTAL_ASIGNACIONES',
       'SALARIO_FAMILIAR', 'DESCUENTOS', 'LIQUIDO','APELLIDO', 'NOMBRE' ]

# %%
parasubir=pd.concat([portal, nuevo], axis=0)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=True'.
#
# To retain the current behavior and silence the warning, pass sort=False
#
#   """Entry point for launching an IPython kernel.

# %%
parasubir=parasubir[['AÑO', 'MES','APELLIDO', 'NOMBRE',  'CARGO', 'TOTAL_ASIGNACIONES', 'SALARIO_FAMILIAR', 'DESCUENTOS',
       'LIQUIDO']]

# %%
parasubir=parasubir.reset_index()

# %%
# imputar=parasubir.TOTAL_ASIGNACIONES.str.replace('.','').str.replace(',','.').str.replace('$', '')[parasubir.TOTAL_ASIGNACIONES.str.replace('.','').str.replace(',','.').str.replace('$', '').notnull()]

# %%
parasubir.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 240 entries, 0 to 239
# Data columns (total 10 columns):
# index                 240 non-null int64
# AÑO                   240 non-null int64
# MES                   240 non-null int64
# APELLIDO              240 non-null object
# NOMBRE                240 non-null object
# CARGO                 240 non-null object
# TOTAL_ASIGNACIONES    240 non-null float64
# SALARIO_FAMILIAR      240 non-null object
# DESCUENTOS            240 non-null float64
# LIQUIDO               240 non-null float64
# dtypes: float64(3), int64(3), object(4)
# memory usage: 18.8+ KB

# %%
parasubir['SALARIO_FAMILIAR']=parasubir['SALARIO_FAMILIAR'].astype(str)

# %%
parasubir['SALARIO_FAMILIAR']=parasubir['SALARIO_FAMILIAR'].str.replace(' ','').str.replace('-','0').astype(float)

# %% [markdown]
# ## Si hace falta corregir el formato de los montos

# %%
parasubir['TOTAL_ASIGNACIONES'][parasubir.TOTAL_ASIGNACIONES.str.replace('.','').str.replace(',','.').str.replace('$', '').notnull()]=imputar



imputar2=parasubir.SALARIO_FAMILIAR.str.replace('.','').str.replace(',','.').str.replace('$', '')[parasubir.SALARIO_FAMILIAR.str.replace('.','').str.replace(',','.').str.replace('$', '').notnull()]

parasubir['SALARIO_FAMILIAR'][parasubir.SALARIO_FAMILIAR.str.replace('.','').str.replace(',','.').str.replace('$', '').notnull()]=imputar2

imputar2=parasubir.DESCUENTOS.str.replace('.','').str.replace(',','.').str.replace('$', '')[parasubir.DESCUENTOS.str.replace('.','').str.replace(',','.').str.replace('$', '').notnull()]
parasubir['DESCUENTOS'][parasubir.DESCUENTOS.str.replace('.','').str.replace(',','.').str.replace('$', '').notnull()]=imputar2[parasubir.DESCUENTOS.str.replace('.','').str.replace(',','.').str.replace('$', '').notnull()]=imputar2

imputar2=parasubir.LIQUIDO.str.replace('.','').str.replace(',','.').str.replace('$', '')[parasubir.LIQUIDO.str.replace('.','').str.replace(',','.').str.replace('$', '').notnull()]
parasubir['LIQUIDO'][parasubir.LIQUIDO.str.replace('.','').str.replace(',','.').str.replace('$', '').notnull()]=imputar2[parasubir.LIQUIDO.str.replace('.','').str.replace(',','.').str.replace('$', '').notnull()]=imputar2

parasubir.SALARIO_FAMILIAR=parasubir.SALARIO_FAMILIAR.fillna(0)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
parasubir=parasubir[[ 'AÑO', 'MES', 'APELLIDO', 'NOMBRE', 'CARGO',
       'TOTAL_ASIGNACIONES', 'SALARIO_FAMILIAR', 'DESCUENTOS', 'LIQUIDO']]

# %%
parasubir
# Out:
#       AÑO  MES           APELLIDO            NOMBRE  \
# 0    2018    1              ACUÑA     MARIA SOLEDAD
# 1    2018    1           ASTARLOA     GABRIEL MARIA
# 2    2018    1           AVOGADRO      ENRIQUE LUIS
# 3    2018    1            BENEGAS          FERNANDO
# 4    2018    1          BOU PEREZ         ANA MARIA
# 5    2018    1           CARRILLO           FACUNDO
# 6    2018    1     COELHO CHICANO         CHRISTIAN
# 7    2018    1         COSTANTINO    SERGIO GABRIEL
# 8    2018    1       D'ALESSANDRO    MARCELO SILVIO
# 9    2018    1       DI BENEDETTO          FEDERICO
# 10   2018    1          FERNANDEZ      DIEGO HERNAN
# 11   2018    1            FERRERO          GENOVEVA
# 12   2018    1              FREDA    MONICA BEATRIZ
# 13   2018    1             GIUSTI         JOSE LUIS
# 14   2018    1         LEGUIZAMON   ISABELLA KARINA
# 15   2018    1              LOPEZ            MATIAS
# 16   2018    1       MACCHIAVELLI   EDUARDO ALBERTO
# ...

# %%
parasubir.to_csv('sueldo-funcionarios-1-8.csv', index=False)
